# %%
import pandas as pd

# import cleaned versions of files

# orderlines_cl.csv
url = 'https://drive.google.com/file/d/1lrSr_vVbXN7QSVSScf68DpWwvCMclK5m/view?usp=sharing' 
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
print(path)
orderlines = pd.read_csv(path)

# orders_cl.csv
url = 'https://drive.google.com/file/d/1cGjJ9o3vtwjK0Sohyr3YVTccXfnTPijT/view?usp=sharing' 
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
orders = pd.read_csv(path)

# brands_cl.csv
url = 'https://drive.google.com/file/d/1XGyabaa4mAkjixMk3XPgx_14OoSse3rs/view?usp=sharing' 
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
brands = pd.read_csv(path)

# products_cl.csv
url = 'https://drive.google.com/file/d/1rHC8M-HG13FtVncImXBydgDtIHyCPH0g/view?usp=sharing' 
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
products = pd.read_csv(path)


pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_rows', 1000)
# Out:
# https://drive.google.com/uc?export=download&id=1lrSr_vVbXN7QSVSScf68DpWwvCMclK5m

# %%
import pandas as  pd
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1BLEHcP-9fm9Rv7A01H3co2XBMnSr66YC')

# %%
#plot the histogram of it's column values
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f95abd76290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f95abd51790>]],
#       dtype=object)

# %%
#display the columns 
df.columns
# Out:
# Index(['order_id', 'created_date', 'total_paid', 'state'], dtype='object')

# %%
orders.sample(5)
# Out:
#         order_id         created_date  total_paid            state  \
# 31832     334203  2017-03-11 21:10:44      124.98          Pending
# 175188    494205  2018-01-18 23:13:14        0.00  Shopping Basket
# 76517     383209  2017-07-28 10:18:52       11.99  Shopping Basket
# 129131    442736  2017-11-25 10:06:10       16.03        Completed
# 139538    454135  2017-12-03 01:28:53     3563.57  Shopping Basket
#
#         check_orders
# 31832           True
# 175188          True
# 76517           True
# 129131          True
# 139538          True

# %%
orders.shape[0]
# Out:
# 204691

# %% [markdown]
# # Things to check:
#
# * [x] take a look at dates, do they match between orders and orderlines.
# * [_] info between orders and orderlines:
#     * [x] do we have the same orders on both df?
#     * [_] revenue? Check if prices between products and orderlines match.

# %%
orders.sample(5)
# Out:
#         order_id         created_date  total_paid            state  \
# 127976    441484  2017-11-24 20:29:02       83.23  Shopping Basket
# 120294    432572  2017-11-22 23:15:16     1170.59  Shopping Basket
# 72784     378924  2017-07-18 10:56:41      103.99  Shopping Basket
# 87250     395243  2017-09-01 11:18:44      499.00        Completed
# 100285    409940  2017-10-08 10:45:04       96.58  Shopping Basket
#
#         check_orders
# 127976          True
# 120294          True
# 72784           True
# 87250           True
# 100285          True

# %%
orderlines.sample(5)
# Out:
#              id  id_order  product_id  product_quantity        sku  \
# 129893  1376524    411755           0                 1    IFX0170
# 138953  1392677    419700           0                 2    APP0698
# 17183   1159115    314765           0                 1  CRU0045-A
# 196344  1488066    459523           0                 1    SAT0057
# 169517  1450036    444679           0                 1    APP0927
#
#         unit_price                 date  total_price  check_orders
# 129893      113.99  2017-10-12 12:54:16       113.99          True
# 138953        9.99  2017-10-30 11:21:16        19.98          True
# 17183       125.40  2017-01-25 15:42:38       125.40          True
# 196344       86.99  2017-12-11 10:20:05        86.99          True
# 169517       17.09  2017-11-26 08:21:09        17.09          True

# %%
orders.shape[0]
# Out:
# 204691

# %%
temp = orderlines.copy()

# %%
orderlines.drop('check_orders',axis=1)
# Out:
#              id  id_order  product_id  product_quantity      sku  unit_price  \
# 0       1119109    299539           0                 1  OTT0133       18.99
# 1       1119110    299540           0                 1  LGE0043      399.00
# 2       1119111    299541           0                 1  PAR0071      474.05
# 3       1119112    299542           0                 1  WDT0315       68.39
# 4       1119113    299543           0                 1  JBL0104       23.74
# ...         ...       ...         ...               ...      ...         ...
# 293738  1650199    527398           0                 1  JBL0122       42.99
# 293739  1650200    527399           0                 1  PAC0653      141.58
# 293740  1650201    527400           0                 2  APP0698        9.99
# 293741  1650202    527388           0                 1  BEZ0204       19.99
# 293742  1650203    527401           0                 1  APP0927       13.99
#
#                        date  total_price
# 0       2017-01-01 00:07:19        18.99
# 1       2017-01-01 00:19:45       399.00
# 2       2017-01-01 00:20:57       474.05
# 3       2017-01-01 00:51:40        68.39
# 4       2017-01-01 01:06:38        23.74
# ...                     ...          ...
# 293738  2018-03-14 13:57:25        42.99
# 293739  2018-03-14 13:57:34       141.58
# 293740  2018-03-14 13:57:41        19.98
# 293741  2018-03-14 13:58:01        19.99
# 293742  2018-03-14 13:58:36        13.99
#
# [293743 rows x 8 columns]

# %%
# check if order id on orders exist on orderlines
(
pd.DataFrame(orders["order_id"])
    .rename(columns={"order_id":"id_order"})
    .assign(is_in_orderlines = lambda x: x["id_order"].isin(orderlines["id_order"]))
    .query("is_in_orderlines == False")
).shape[0]
# Out:
# 0

# %%
# check of order id on orderlines exists on orders
(
pd.DataFrame(orderlines["id_order"])
    .rename(columns={"id_order":"order_id"})
    .assign(is_in_orders = lambda x: x["order_id"].isin(orders["order_id"]))
    .query("is_in_orders == False")
).shape[0]
# Out:
# 0

# %%
orders.head()
# Out:
#    order_id         created_date  total_paid      state  check_orders
# 0    241319  2017-01-02 13:35:40       44.99  Cancelled          True
# 1    241423  2017-11-06 13:10:02      136.15  Completed          True
# 2    242832  2017-12-31 17:40:03       15.76  Completed          True
# 3    243330  2017-02-16 10:59:38       84.98  Completed          True
# 4    243784  2017-11-24 13:35:19      157.86  Cancelled          True

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
(
orderlines
    .groupby(["id_order"])
    .agg(total_price = ("total_price","sum"))
    .reset_index()
    .merge(orders, how="inner", left_on = "id_order", right_on = "order_id")
    .filter(["id_order","total_price","total_paid"])  
    .assign(diff = lambda x: x["total_paid"] - x["total_price"])
    .query("diff < 0.02 & diff > 0")
    .sum()
)
# Out:
# id_order      3885483363.00000
# total_price     16073735.01000
# total_paid      16073799.13000
# diff                  64.12000
# dtype: float64

# %%
(
orderlines
    .groupby(["id_order"])
    .agg(total_price = ("total_price","sum"))
    .reset_index()
    .merge(orders, how="inner", left_on = "id_order", right_on = "order_id")
    .filter(["id_order","total_price","total_paid"])
    .assign(diff = lambda x: x["total_paid"] - x["total_price"])
    # .query("diff < 0.02 & diff > 0")
    # .sum()
    .query("0.02 < diff < 30")
    .sample(10)

)
# Out:
#         id_order  total_price  total_paid     diff
# 175855    494999     61.98000    81.97000 19.99000
# 15085     316021    289.99000   294.98000  4.99000
# 6268      306352     15.98000    20.96000  4.98000
# 154290    470473     32.99000    36.98000  3.99000
# 17331     318574    199.99000   204.98000  4.99000
# 148223    463587    104.99000   111.98000  6.99000
# 173321    492127    169.41000   189.40000 19.99000
# 7655      307855     49.99000    56.98000  6.99000
# 13151     313874    339.97000   344.97000  5.00000
# 61406     366309    174.99000   181.98000  6.99000

# %%
#df_temp['diff'] =  df_temp["total_paid"] - df_temp["total_price"]

# %% [markdown]
# ### Explanation how to use `DataFrame.merge()`

# %% [markdown]
# Create discounts columns on orderlines:

# %%
discounts = (
orderlines
    .filter(["id_order","sku","unit_price"])
    .merge(products.filter(["sku","desc","max_price_orderlines"]), on="sku", how="left")
    .assign(disc = lambda x: x["max_price_orderlines"] - x["unit_price"])
    .assign(disc_perc = lambda x: (1- (x["unit_price"]/ x["max_price_orderlines"])) * 100 )
    .dropna()
)
discounts
# Out:
#         id_order      sku  unit_price  \
# 37        299576  SAM0095       82.64
# 174       299695  PAC1400       90.99
# 331       299860  PAC1516      457.89
# 357       299881  SAN0137       49.39
# 375       299902  IOT0018       23.74
# ...          ...      ...         ...
# 293598    527286  APP2490     1159.00
# 293671    527342  APP2492     1329.00
# 293696    527364  APP2491     1329.00
# 293702    527367  REP0250       69.90
# 293704    527367  REP0299       59.99
#
#                                                      desc  \
# 37      SSD Hard Drive SATA 6 Gb / s 25-inch NAND tech...
# 174     Control on / off and power / consumer remote s...
# 331     NAS server with 8GB of RAM memory 2 Gigabit po...
# 357                                   SSD 120GB 25 inches
# 375     Magnetic car holder compatible with all models...
# ...                                                   ...
# 293598                New Apple iPhone 64GB Free Silver X
# 293671               New Apple iPhone X 256GB Silver Free
# 293696           New Apple iPhone X 256GB Free Space Gray
# 293702  Repair service including parts and labor for i...
# 293704  Repair service including parts and labor for i...
#
#         max_price_orderlines  disc  disc_perc
# 37                     86.99  4.35       5.00
# 174                    96.99  6.00       6.19
# 331                   484.99 27.10       5.59
# 357                    63.58 14.19      22.32
# 375                    24.99  1.25       5.00
# ...                      ...   ...        ...
# 293598               1159.00  0.00       0.00
# 293671               1329.00  0.00       0.00
# 293696               1329.00  0.00       0.00
# 293702                 69.90  0.00       0.00
# 293704                 59.99  0.00       0.00
#
# [7326 rows x 7 columns]

# %%
products.head(100)
# Out:
#           sku                                               name  \
# 0     RAI0007                  Silver Rain Design mStand Support
# 1     APP0023                  Apple Mac Keyboard Keypad Spanish
# 2     APP0025                   Mighty Mouse Apple Mouse for Mac
# 3     APP0072      Apple Dock to USB Cable iPhone and iPod white
# 4     KIN0007        Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# 5     APP0073     Apple Composite AV Cable iPhone and iPod white
# 6     KIN0008        Mac Memory Kingston 1GB 667MHz DDR2 SO-DIMM
# 7     KIN0009        Mac Memory Kingston 2GB 800MHz DDR2 SO-DIMM
# 8   KIN0001-2  Mac memory Kingston 4GB (2x2GB) 667MHz DDR2 SO...
# 9     APP0100             Apple Adapter Mini Display Port to VGA
# 10    APP0101              Apple Mini DisplayPort to DVI Adapter
# 11    SEN0021  Sennheiser CX 300-II Precision headphones iPho...
# 12    APP0111                     Apple USB Ethernet Adapter Mac
# 13    APP0156              45W MagSafe charger Apple MacBook Air
# 14    MOS0013         Adapter Moshi FireWire 400 to FireWire 800
# 15    MOS0021               Clearguard Moshi MacBook Pro and Air
# 16    APP0206  60W MagSafe charger Apple MacBook and MacBook ...
# 17    HGD0007       Henge Docks Docking Station MacBook Pro 13 "
# 18    MUV0009    Muvit Back Clear Case iPhone 4 / 4S Transparent
# 19    APP0234                        Apple Dock Connector to VGA
# 20    APP0247    85W MagSafe charger Apple MacBook Pro 15 "/ 17"
# 21    APP0233             Apple iPad Camera Connection connector
# 22    JMO0014                   Just Mobile Upstand iPad support
# 23    MOB0007            Mobee Magic Charger Charger Magic Mouse
# 24    APP0277         Apple Wireless Keyboard Keyboard (OEM) Mac
# 25    MOP0011  Mophie Juice Pack Air Battery Case iPhone 4 / ...
# 26    APP0280                      Apple HDMI to HDMI Cable 1.8m
# 27    OND0069                           Adapter mini DVI to HDMI
# 28    SNN0007              Sonnet Tempo SATA PCIe Mac and PC E2P
# 29    KIN0025          Mac memory DIMM DDR3 2GB 1333MHz Kingston
# 30    OND0073                 Mini DisplayPort to HDMI Cable 18m
# 31    MOS0042             Adapter Moshi Mini Display Port to VGA
# 32    BEL0070        Music Receiver Belkin iPhone music receiver
# 33    LMP0007                    KeyPad LMP Bluetooth Keypad Mac
# 34    TWS0019  Twelve South MagicWand support Apple Magic Tra...
# 35    BEL0072                Belkin PRO Series USB 2.0 Cable 18M
# 36    APP0308  AV Cable Adapter Apple iPhone iPad and iPod white
# 37    GRT0196  Griffin Survivor Extreme-Duty Case iPad 2 3 an...
# 38    MUV0023  Extreme Muvit iPhone and iPod BikeMount sleeve...
# 39    JMO0026        Just Mobile Lazy Couch Support Mac and iPad
# 40    OWC0007  OWC Data Doubler Optical Bay adapter Macbook /...
# 41    KEN0028               Kensington ClickSafe lock Mac and PC
# 42    APP0343                   Apple Thunderbolt Cable 2m White
# 43    MOS0044                           Moshi FireWire 800 Cable
# 44    MOS0062                         Moshi USB Ethernet Adapter
# 45    MOB0009          Mobee Magic Numpad for the Magic Trackpad
# 46    TWS0026  Twelve South BookBook MacBook Air sleeve 11 "b...
# 47    MOB0010            Additional Battery Pack Mobee Magic Bar
# 48    IST0009                    iStabilizer iPhone Tripod Mount
# 49    TWS0027  Twelve South BookBook Case MacBook Air / Pro 1...
# 50    APP0367  Apple Mini DisplayPort to DVI Adapter Mac dual...
# 51    APP0344          Apple Thunderbolt Display 27 "Monitor Mac
# 52    BLL0008                  BlueLounge CableDrop Pack 6 Black
# 53    BLL0009                  BlueLounge CableDrop Pack 6 White
# 54    BLL0011      BlueLounge Milo iPhone and iPod black support
# 55    BLL0012      Milo BlueLounge support iPhone and iPod white
# 56  KIN0002-2  Mac memory Kingston 2GB (2x1GB) 667MHz DDR2 SO...
# 57  KIN0003-2  Mac memory Kingston 4GB (2x2gb) SO-DIMM DDR2 8...
# 58    MOP0013  Mophie Juice Pack Air Battery Case iPhone 4 / ...
# 59    MOS0065                    Moshi TeraGlove cleaner screens
# 60    WAC0032   Wacom Bamboo Stylus Pack 3 first generation tips
# 61    SPE0077   Speck SeeThru Satin shell MacBook Pro 13 "Morado
# 62    SPE0045     Speck SeeThru Satin Case Macbook Air 11 "Black
# 63    WIT0009  Withings Wireless Scale Scale iPhone iPad & iP...
# 64    LAC0141  LaCie Porsche Design 1TB External Hard Drive M...
# 65    HGD0012            Henge Docks Click keyboard support iMac
# 66    MAK0008  Maclocks theft case iPad 2 3 and 4 black with ...
# 67    MAK0007  Maclocks theft case iPad 2 3 and 4 transparent...
# 68    MAK0009     Maclocks theft case iPad 2 3 and 4 transparent
# 69    MAK0010           Maclocks theft case iPad 2 3 and 4 black
# 70    MAK0012              Maclocks theft cover Macbook Air 13 "
# 71    SEA0039  Seagate Barracuda 2TB 35 "SATA hard drive Mac ...
# 72    SYN0047              Synology Pack 1 license for IP camera
# 73    SYN0048                 Synology Pack 4 IP camera licenses
# 74    SYN0051         Sliding Rail kit synology 2U sliding rails
# 75    WAC0040  Wacom Bamboo Wireless Kit / Intuos graphics ta...
# 76    WAC0045                   Wacom Intuos Airbrush stylus 4/5
# 77    WAC0046                     Intuos Wacom stylus ArtPen 5/4
# 78    SEA0044  Seagate Barracuda 3TB 35 "SATA hard drive Mac ...
# 79    APP0370                              Apple TV media player
# 80    MOB0012             Mobee Magic Trackpad Charger Power Bar
# 81    MOS0073  Moshi iVisor AG Retina iPad Protector (3G / 4G...
# 82    WDT0127  Western Digital Green 1TB 35 "5400pm hard driv...
# 83    OTR0045  External Slim Case for SuperDrive MacBook / Ma...
# 84    IKM0013  IK Multimedia iRig MIX DJ Mixer iPhone iPad an...
# 85    IKM0014  IK Multimedia iRig Stomp Guitar Pedal iPhone i...
# 86    KEN0045       Kensington Essentials Stand iPad Stand black
# 87    KEN0046       Kensington Essentials Stand iPad Stand white
# 88    IKM0015  IK Multimedia iRig PRE microphone adapter iPho...
# 89    IKM0016  IK Multimedia iRig MIC Cast iPhone iPad and iP...
# 90    PAC0023        OWC Data Doubler Pack MacBook / MacBook Pro
# 91    HGD0015       Henge Docks Docking Station MacBook Air 13 "
# 92    GRT0249  Griffin Helo TC Assault Helicopter iPhone iPad...
# 93    OWC0008  OWC Data Doubler Optical Bay Adapter Mac Mini ...
# 94    WAC0054          Wacom Bamboo Pen (pen parts for CTL-470K)
# 95    WAC0055            Wacom Intuos Professional Accessory Kit
# 96    WAC0058  Wacom Intuos 5/4 Grip Pen (Replacement pen) Ma...
# 97    MAK0014  Maclocks safety housing Kiosk iPad 2 3 and 4 b...
# 98    MAK0015            Stick Maclocks silver metal safely iPad
# 99    SEA0049  Seagate Barracuda 1TB Hard Drive 35 "SATA for ...
#
#                                                  desc   price       type  \
# 0        Aluminum support compatible with all MacBook   59.99       8696
# 1           USB ultrathin keyboard Apple Mac Spanish.   59.00   13855401
# 2                              mouse Apple USB cable.   59.00       1387
# 3               IPhone dock and USB Cable Apple iPod.   25.00       1230
# 4   2GB RAM Mac mini and iMac (2006/07) MacBook Pr...   34.99       1364
# 5   IPhone and iPod AV Cable Dock to Composite Video.   45.00       1230
# 6   1GB RAM Mac mini and iMac (2006/07) MacBook Pr...   18.99       1364
# 7        2GB RAM iMac with Intel Core 2 Duo (Penryn).   36.99       1364
# 8   RAM 4GB (2x2GB) Mac mini and iMac (2006/07) Ma...   74.00       1364
# 9   Adapter Mini Display Port to VGA MacBook and M...   35.00       1325
# 10  Adapter mini DisplayPort to DVI MacBook and Ma...   35.00       1325
# 11     Headphones iPhone iPad iPad 2 iPad 3 and iPod.   49.99       5384
# 12                       USB to Ethernet adapter Mac.   35.00       1334
# 13     Charger MacBook Air MagSafe 45 W (MC747Z / A).   89.00   13005399
# 14           FireWire 400 adapter cable FireWire 800.   20.00       1325
# 15  Keyboard Protector MacBook Pro 13-inch Retina ...   24.95   13835403
# 16  Charger MacBook and 13 inch MacBook MagSafe 60...   89.00   13005399
# 17  Dock and support with multiple connections for...   69.99   12995397
# 18                  Case iPhone 4 / 4S polycarbonate.    9.99   11865403
# 19                         Dock Connector to VGA IOS.   35.00   13955395
# 20     Charger MacBook Pro MagSafe 85 W (MC556Z / A).   89.00   13005399
# 21   IPad connector for digital cameras and SD cards.   35.00   13955395
# 22        Support Retina iPad and iPad mini aluminum.   49.95       1216
# 23                   Wireless Charger for Magic Mouse   49.99   12355400
# 24  Ultrathin keyboard Apple Bluetooth Spanish (un...   79.00   13855401
# 25          Battery Case iPhone 4 / 4S rigid polymer.   69.99   5,49E+11
# 26                           HMDI to HDMI Cable 1.8m.   25.00       1325
# 27            Adapter mini DVI to HDMI for Mac and PC   16.49       1325
# 28      PCIe Card with 2 Serial ATA ports Mac and PC.   59.99       1276
# 29                       2GB RAM Mac Pro (July 2010).   29.99       1364
# 30  Cable with Mini DisplayPort to HDMI (audio + v...   22.99       1325
# 31            Cable Adapter Mini Display Port to VGA.   34.99       1325
# 32  Music Receiver iPhone iPad and iPod Touch for ...   49.99   11905404
# 33    expansion keypad Mac with bluetooth connection.   54.99   13855401
# 34  MagicWand for wireless keyboard and Magic Trac...     NaN       8696
# 35  USB Cable USB type A and type B 18m in length ...    3.99       1325
# 36             IPhone iPad iPod adapter and AV cable.   45.00       1230
# 37   IPad 2 Case 3 and 4 for extreme ultra resistant.   64.99   12635403
# 38  IPhone and iPod support sleeve waterproof App ...   35.90   11865403
# 39                     Mac and iPad small lift stand.   19.95       8696
# 40      Tray SuperDrive replacement hard disk or SSD.   72.99   12755395
# 41                      Mac and PC padlock with keys.   54.99       1325
# 42                    Cable Mac Apple Thunderbolt 2m.   45.00       1325
# 43                           FireWire 800 Cable 18 m.   34.99       1325
# 44                           USB to Ethernet adapter.   29.00       1325
# 45             3 Numeric for Magic Trackpad stickers.   29.49   12355400
# 46  Case Macbook 11 inches vintage skin with soft ...   79.99   13835403
# 47                Pack extra battery Mobee Magic Bar.   29.99   12355400
# 48         IPhone Tripod Adapter for photo and video.   19.99       1216
# 49  Funda Macbook Air / Pro 13 inch vintage leathe...   79.99   13835403
# 50  Adapter Mini Display Port to DVI dual channel ...  119.00       1325
# 51  Monitor Display 27-inch Apple Thunderbolt (MC9... 1149.00       1296
# 52         Cable management Mac iPhone iPad and iPod.   11.99   12285400
# 53         Cable management Mac iPhone iPad and iPod.   12.99   12285400
# 54                   Desktop support iPhone and iPod.   14.99       1216
# 55                   Desktop support iPhone and iPod.   14.99       1216
# 56  RAM 2GB (2x1GB) Mac mini and iMac (2006/07) Ma...   37.98       1364
# 57  RAM 4GB (2x2gb) iMac with Intel Core 2 Duo (Pe...   73.98       1364
# 58      Case Battery (1500mAh) iPhone 4 / 4S polymer.   69.95   5,49E+11
# 59  Microfibre screen cleaner for Mac iPhone iPad ...   20.00   12355400
# 60  3 Pack Bamboo Stylus pen tips iPad iPhone and ...    4.99       1229
# 61                        Macbooks housing 13 inches.   49.90   13835403
# 62                rigid housing MacBook Air 11 inches   49.90   13835403
# 63  Scale WS-30 iPhone iPad and iPod Touch applica...   99.95   11905404
# 64         External Hard Drive Mac and PC USB 3.0 1TB   79.99   11935397
# 65  Base to hold the Apple Magic TrackPad and Wire...   29.00       8696
# 66  Case antitheft iPad 2 3 and 4 polycarbonate ro...  120.00   12635403
# 67  Case antitheft iPad 2 3 and 4 polycarbonate ro...  120.00   12635403
# 68  Case antitheft iPad 2 3 and 4 polycarbonate su...   79.99   12635403
# 69  Case antitheft iPad 2 3 and 4 polycarbonate su...   79.99   12635403
# 70  Theft Case MacBook Air 13-inch polycarbonate w...   79.99   13835403
# 71   Internal Hard Drive 2TB Mac and PC (ST2000DM006)   89.99   12655397
# 72                  1 Pack license Mac and PC camera.   52.99       1404
# 73                 4 Pack licenses Mac and PC camera.  181.99       1404
# 74               Shelf rail kit Synology RackStation.  102.49       1404
# 75               Wireless Kit Wacom graphics tablets.   39.99  101781405
# 76  stylus for pen tablets Cintiq 21UX Intuos 4/5 ...  109.90       1229
# 77  special stylus Mac and PC for Intuos4 graphics...  109.90       1229
# 78  internal hard drive Mac and PC 3TB (ST3000DM008).  112.00   12655397
# 79                           Apple multimedia player.   79.00       4259
# 80                        Charger for Magic Trackpad.   29.49   13005399
# 81            Retina iPad Protector free air bubbles.   29.95   14035403
# 82  WD Internal Hard Drive Mac and PC 1TB (WD10EZRX).   65.00   12655397
# 83  External SuperDrive case for MacBook and MacBo...   35.00   12995397
# 84                     Dj mixer iPhone iPad and iPod.  121.99   11905404
# 85                 Guitar Pedal iPhone iPad and iPod.   73.19   11905404
# 86                Universal support for iPad tablets.   29.99       1216
# 87                Universal support for iPad tablets.   19.99       1216
# 88           Microphone Adapter iPhone iPad and iPod.   48.79   11905404
# 89                   iPhone iPad and iPod microphone.   48.79   11905404
# 90  Pack Replacement Superdrive for SSD / HDD + bo...  107.99   12755395
# 91           Dock MacBook Air 13-inch multi-function.   79.99       8696
# 92  Remote Control Helicopter iPhone iPad and iPod...   59.99   12285400
# 93  Tray substitution of superdrive by hard drive ...   72.99   12755395
# 94                      Replacement pen for CTL-470K.   34.90       1229
# 95                              Intuos accessory kit.   24.90  101781405
# 96                        wireless stylus Mac and PC.   79.99       1229
# 97  Holder and housing iPad 2 3 and 4 aluminum and...  164.99       1216
# 98                    Security lock plate steel iPad.   49.99   12085400
# 99   internal hard drive Mac and PC 1TB (ST1000DM010)   59.00   12655397
#
#     max_price_orderlines
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# 30                   NaN
# 31                   NaN
# 32                   NaN
# 33                   NaN
# 34                 29.99
# 35                   NaN
# 36                   NaN
# 37                   NaN
# 38                   NaN
# 39                   NaN
# 40                   NaN
# 41                   NaN
# 42                   NaN
# 43                   NaN
# 44                   NaN
# 45                   NaN
# 46                   NaN
# 47                   NaN
# 48                   NaN
# 49                   NaN
# 50                   NaN
# 51                   NaN
# 52                   NaN
# 53                   NaN
# 54                   NaN
# 55                   NaN
# 56                   NaN
# 57                   NaN
# 58                   NaN
# 59                   NaN
# 60                   NaN
# 61                   NaN
# 62                   NaN
# 63                   NaN
# 64                   NaN
# 65                   NaN
# 66                   NaN
# 67                   NaN
# 68                   NaN
# 69                   NaN
# 70                   NaN
# 71                   NaN
# 72                   NaN
# 73                   NaN
# 74                   NaN
# 75                   NaN
# 76                   NaN
# 77                   NaN
# 78                   NaN
# 79                   NaN
# 80                   NaN
# 81                   NaN
# 82                   NaN
# 83                   NaN
# 84                   NaN
# 85                   NaN
# 86                   NaN
# 87                   NaN
# 88                   NaN
# 89                   NaN
# 90                   NaN
# 91                   NaN
# 92                   NaN
# 93                   NaN
# 94                   NaN
# 95                   NaN
# 96                   NaN
# 97                   NaN
# 98                   NaN
# 99                   NaN

# %% [markdown]
# 1) What is the average difference between total_paid and unit_price_total?

# %%
orders_info = (
orderlines
    .groupby('id_order')
    .agg({'total_price':'sum'})
    .merge(orders, how='left', left_on='id_order', right_on='order_id')
    .copy()
)
orders_info['price_difference'] = orders_info['total_price'] - orders_info['total_paid']
orders_info.describe()
# Out:
#        total_price     order_id   total_paid  price_difference
# count 204691.00000 204691.00000 204691.00000      204691.00000
# mean     628.55423 412606.27856    630.85762          -2.30339
# std     1845.12974  65990.93385   1844.40553         297.46183
# min        0.00000 241319.00000      0.00000      -90898.61000
# 25%       49.90000 355076.50000     49.99000          -0.01000
# 50%      149.99000 412255.00000    151.38000           0.00000
# 75%      664.42000 469541.00000    664.98000           0.00000
# max   250802.37000 527401.00000 214747.53000       36159.90000

# %% [markdown]
# 2) What is the distribution of these differences?

# %% [markdown]
# 3) Can all the differences be explained by shipping
# costs? If not, what are other plausible explanations?
#
# No, possible plausible explanations:
# *   some of the highest price differences are due to corruption of data
# *   still after removing outliers the highest positive differences in orders that have not been completed yet, maybe just some of the products in the shopping basket have been bought?
# *   Listeneintrag

# %%
orders_info = (
orderlines
    .groupby('id_order')
    .agg({'total_price':'sum'})
    .merge(orders, how='left', left_on='id_order', right_on='order_id')
    .copy()
)
orders_info['price_difference'] = orders_info['total_price'] - orders_info['total_paid']
orders_info.describe()

#orders_info.sort_values('price_difference', ascending = False).head(10)
#orders_info[['total_price', 'total_paid', 'price_difference']].sort_values('price_difference', ascending = False).tail(200)
# Out:
#        total_price  order_id  total_paid  price_difference
# count    204691.00 204691.00   204691.00         204691.00
# mean        628.55 412606.28      630.86             -2.30
# std        1845.13  65990.93     1844.41            297.46
# min           0.00 241319.00        0.00         -90898.61
# 25%          49.90 355076.50       49.99             -0.01
# 50%         149.99 412255.00      151.38              0.00
# 75%         664.42 469541.00      664.98              0.00
# max      250802.37 527401.00   214747.53          36159.90

# %% [markdown]
# 4) If there are differences that you can’t explain: what should you do with these orders?
