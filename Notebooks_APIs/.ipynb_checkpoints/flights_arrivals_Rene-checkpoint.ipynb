# %%
import pandas as pd
from datetime import datetime
import pytz
import requests

# %%
import requests

url = "https://aerodatabox.p.rapidapi.com/flights/airports/icao/EHAM/2022-08-15T08:00/2022-08-15T20:00"

querystring = {"withLeg":"true","direction":"Arrival","withCancelled":"true","withCodeshared":"true","withCargo":"true","withPrivate":"true","withLocation":"false"}

headers = {
	"X-RapidAPI-Key": "41ff370a44mshbe20330f78fd706p154d9ajsnaa91e9e7fba0",
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"arrivals":[{"departure":{"airport":{"icao":"LFST","iata":"SXB","name":"Strasbourg"},"quality":[]},"arrival":{"scheduledTimeLocal":"2022-08-15 08:05+02:00","actualTimeLocal":"2022-08-15 08:05+02:00","runwayTimeLocal":"2022-08-15 07:57+02:00","scheduledTimeUtc":"2022-08-15 06:05Z","actualTimeUtc":"2022-08-15 06:05Z","runwayTimeUtc":"2022-08-15 05:57Z","quality":["Basic","Live"]},"number":"AF 4054","status":"Canceled","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Embraer RJ145"},"airline":{"name":"Air France"}},{"departure":{"airport":{"icao":"KSEA","iata":"SEA","name":"Seattle"},"quality":[]},"arrival":{"scheduledTimeLocal":"2022-08-15 08:40+02:00","actualTimeLocal":"2022-08-15 10:14+02:00","runwayTimeLocal":"2022-08-15 10:14+02:00","scheduledTimeUtc":"2022-08-15 06:40Z","actualTimeUtc":"2022-08-15 08:14Z","runwayTimeUtc":"2022-08-15 08:14Z","terminal":"3","baggageBelt":"15","quality":["Basic","Live"]},"number":"AF 5597","status":"Arrived","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Airbus A330-900 NEO"},"airline":{"name":"Air France"}},{"departure":{"airport":{"icao":"LFBO","iata":"TLS","name":"Toulouse-Blagnac"},"quality":[]},"arrival":{"scheduledTimeLocal":"2022-08-15 08:20+02:00","actualTimeLocal":"2022-08-15 08:03+02:00","runwayTimeLocal":"2022-08-15 08:03+02:00","scheduledTimeUtc":"2022-08-15 06:20Z","actualTimeUtc":"2022-08-15 06:03Z","runwayTimeUtc":"2022-08-15 06:03Z","terminal":"2","baggageBelt":"11","quality":["Basic","Live"]},"number":"AF 8260","status":"Arrived","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Boeing 737-700 (winglets)"},"airline":{"name":"Air France"}},{"departure":{"airport":{"icao":"LIMC","iata":"MXP","name":"Milan"},"quality":[]},"arrival":{"scheduledTimeLocal":"2022-08-15 08:35+02:00","actualTimeLocal":"2022-08-15 08:06+02:00","runwayTimeLocal":"2022-08-15 08:06+02:00","scheduledTimeUtc":"2022-08-15 06:35Z","actualTimeUtc":"2022-08-15 06:06Z","runwayTimeUtc":"2022-08-15 06:06Z","terminal":"2","baggageBelt":"12","quality":["Basic","Live"]},"number":"AM 6459","status":"Arrived","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Boeing 737-800 (winglets)"},"airline":{"name":"Aeromexico"}},{"departure":{"airport":{"icao":"LSZH","iata":"ZRH","name":"Zurich"},"quality":[]},"arrival":{"scheduledTimeLocal":"2022-08-15 08:35+02:00","actualTimeLocal":"2022-08-15 08:21+02:00","runwayTimeLocal":"2022-08-15 08:21+02:00","scheduledTimeUtc":"2022-08-15 06:35Z","actualTimeUtc":"2022-08-15 06:21Z","runwayTimeUtc":"2022-08-15 06:21Z","terminal":"2","baggageBelt":"10","quality":["Basic","Live"]},"number":"AM 6471","status":"Arrived","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Embraer 190"},"airline":{"name":"Aeromexico"}},{"departure":{"airport":{"icao":"ENGM","iata":"OSL","name":"Oslo"},"quality":[]},"arrival":{"scheduledTimeLocal":"2022-08-15 08:15+02:00","actualTimeLocal":"2022-08-15 08:02+02:00","runwayTimeLocal":"2022-08-15 08:02+02:00","scheduledTimeUtc":"2022-08-15 06:15Z","actualTimeUtc":"2022-08-15 06:02Z","runwayTimeUtc":"2022-08-15 06:02Z","terminal":"2","baggageBelt":"9","quality":["Basic","Live"]},"number":"AM 6532","status":"Arrived","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Boeing 737-800 (winglets)"},"airline":{"name":"Aeromexico"}},{"departure":{"airport":{"icao":"KDFW","iata":"DFW","name":"Dallas-Fort Worth"},"quality":[]},"arrival":{"scheduledTimeLocal":"2022-08-15 08:40+02:00","actualTimeLocal":"2022-08-15 08:31+02:00","runwayTimeLocal":"2022-08-15 08:31+02:00","scheduledTimeUtc":"2022-08-15 06:40Z","actualTimeUtc":"2022-08-15 06:31Z","runwayTimeUtc":"2022-08-15 06:31Z","terminal":"4","baggageBelt":"19","quality":["Basic","Live"]},"number":"AY 4132","status":"Arrived","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Boeing 787-9"},"airline":{"name":"Finnair"}},{"departure":{"airport":{"icao":"EGCC","iata":"MAN","name":"Manchester ...

# %%
url = "https://aerodatabox.p.rapidapi.com/flights/airports/icao/EHAM/2022-08-15T08:00/2022-08-15T20:00"

querystring = {"withLeg":"true","direction":"Arrival","withCancelled":"true","withCodeshared":"true","withCargo":"true","withPrivate":"true","withLocation":"false"}

headers = {
	"X-RapidAPI-Key": "41ff370a44mshbe20330f78fd706p154d9ajsnaa91e9e7fba0",
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
json = response.json()
json
# Out:
# {'arrivals': [{'departure': {'airport': {'icao': 'LFST',
#      'iata': 'SXB',
#      'name': 'Strasbourg'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:05+02:00',
#     'actualTimeLocal': '2022-08-15 08:05+02:00',
#     'runwayTimeLocal': '2022-08-15 07:57+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:05Z',
#     'actualTimeUtc': '2022-08-15 06:05Z',
#     'runwayTimeUtc': '2022-08-15 05:57Z',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 4054',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer RJ145'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'airport': {'icao': 'KSEA', 'iata': 'SEA', 'name': 'Seattle'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:40+02:00',
#     'actualTimeLocal': '2022-08-15 10:14+02:00',
#     'runwayTimeLocal': '2022-08-15 10:14+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:40Z',
#     'actualTimeUtc': '2022-08-15 08:14Z',
#     'runwayTimeUtc': '2022-08-15 08:14Z',
#     'terminal': '3',
#     'baggageBelt': '15',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 5597',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A330-900 NEO'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'airport': {'icao': 'LFBO',
#      'iata': 'TLS',
#      'name': 'Toulouse-Blagnac'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:20+02:00',
#     'actualTimeLocal': '2022-08-15 08:03+02:00',
#     'runwayTimeLocal': '2022-08-15 08:03+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:20Z',
#     'actualTimeUtc': '2022-08-15 06:03Z',
#     'runwayTimeUtc': '2022-08-15 06:03Z',
#     'terminal': '2',
#     'baggageBelt': '11',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 8260',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-700 (winglets)'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'airport': {'icao': 'LIMC', 'iata': 'MXP', 'name': 'Milan'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:35+02:00',
#     'actualTimeLocal': '2022-08-15 08:06+02:00',
#     'runwayTimeLocal': '2022-08-15 08:06+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:35Z',
#     'actualTimeUtc': '2022-08-15 06:06Z',
#     'runwayTimeUtc': '2022-08-15 06:06Z',
#     'terminal': '2',
#     'baggageBelt': '12',
#     'quality': ['Basic', 'Live']},
#    'number': 'AM 6459',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Aeromexico'}},
#   {'departure': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:35+02:00',
#     'actualTimeLocal': '2022-08-15 08:21+02:00',
#     'runwayTimeLocal': '2022-08-15 08:21+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:35Z',
#     'actualTimeUtc': '2022-08-15 06:21Z',
#     'runwayTimeUtc': '2022-08-15 06:21Z',
#     'terminal': '2',
#     'baggageBelt': '10',
#     'quality': ['Basic', 'Live']},
#    'number': 'AM 6471',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Aeromexico'}},
#   {'departure': {'airport': {'icao': 'ENGM', 'iata': 'OSL', 'name': 'Oslo'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:15+02:00',
#     'actualTimeLocal': '2022-08-15 08:02+02:00',
#     'runwayTimeLocal': '2022-08-15 08:02+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:15Z',
#     'actualTimeUtc': '2022-08-15 06:02Z',
#     'runwayTimeUtc': '2022-08-15 06:02Z',
#     'terminal': '2',
#     'baggageBelt': '9',
#     'quality': ['Basic', 'Live']},
#    'number': 'AM 6532',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Aeromexico'}},
#   {'departure': {'airport': {'icao': 'KDFW',
#      'iata': 'DFW',
#      'name': 'Dallas-Fort Worth'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:40+02:00',
#     'actualTimeLocal': '2022-08-15 08:31+02:00',
#     'runwayTimeLocal': '2022-08-15 08:31+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:40Z',
#     'actualTimeUtc': '2022-08-15 06:31Z',
#     'runwayTimeUtc': '2022-08-15 06:31Z',
#     'terminal': '4',
#     'baggageBelt': '19',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 4132',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-9'},
#    'airline': {'name': 'Finnair'}},
#   {'departure': {'airport': {'icao': 'EGCC',
#      'iata': 'MAN',
#      'name': 'Manchester'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:15+02:00',
#     'actualTimeLocal': '2022-08-15 08:55+02:00',
#     'runwayTimeLocal': '2022-08-15 08:55+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:15Z',
#     'actualTimeUtc': '2022-08-15 06:55Z',
#     'runwayTimeUtc': '2022-08-15 06:55Z',
#     'terminal': '2',
#     'baggageBelt': '11',
#     'quality': ['Basic', 'Live']},
#    'number': 'CI 9496',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-700 (winglets)'},
#    'airline': {'name': 'China'}},
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:40+02:00',
#     'actualTimeLocal': '2022-08-15 08:25+02:00',
#     'runwayTimeLocal': '2022-08-15 08:25+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:40Z',
#     'actualTimeUtc': '2022-08-15 06:25Z',
#     'runwayTimeUtc': '2022-08-15 06:25Z',
#     'terminal': '2',
#     'baggageBelt': '13',
#     'quality': ['Basic', 'Live']},
#    'number': 'CZ 7603',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'China Southern'}},
#   {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:35+02:00',
#     'actualTimeLocal': '2022-08-15 08:17+02:00',
#     'runwayTimeLocal': '2022-08-15 08:17+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:35Z',
#     'actualTimeUtc': '2022-08-15 06:17Z',
#     'runwayTimeUtc': '2022-08-15 06:17Z',
#     'terminal': '2',
#     'baggageBelt': '12',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 8400',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'LDZA', 'iata': 'ZAG', 'name': 'Zagreb'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:15+02:00',
#     'actualTimeLocal': '2022-08-15 08:08+02:00',
#     'runwayTimeLocal': '2022-08-15 08:08+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:15Z',
#     'actualTimeUtc': '2022-08-15 06:08Z',
#     'runwayTimeUtc': '2022-08-15 06:08Z',
#     'terminal': '2',
#     'baggageBelt': '10',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9183',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'LYBE',
#      'iata': 'BEG',
#      'name': 'Belgrade'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:40+02:00',
#     'actualTimeLocal': '2022-08-15 08:30+02:00',
#     'runwayTimeLocal': '2022-08-15 08:30+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:40Z',
#     'actualTimeUtc': '2022-08-15 06:30Z',
#     'runwayTimeUtc': '2022-08-15 06:30Z',
#     'terminal': '2',
#     'baggageBelt': '8',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9195',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'LIRQ', 'iata': 'FLR', 'name': 'Firenze'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:40+02:00',
#     'actualTimeLocal': '2022-08-15 08:24+02:00',
#     'runwayTimeLocal': '2022-08-15 08:24+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:40Z',
#     'actualTimeUtc': '2022-08-15 06:24Z',
#     'runwayTimeUtc': '2022-08-15 06:24Z',
#     'terminal': '2',
#     'baggageBelt': '8',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9478',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'LLBG',
#      'iata': 'TLV',
#      'name': 'Tel Aviv Yafo'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:45+02:00',
#     'actualTimeLocal': '2022-08-15 08:32+02:00',
#     'runwayTimeLocal': '2022-08-15 08:32+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:45Z',
#     'actualTimeUtc': '2022-08-15 06:32Z',
#     'runwayTimeUtc': '2022-08-15 06:32Z',
#     'terminal': '3',
#     'baggageBelt': '16',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9559',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-900 (winglets) '},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:20+02:00',
#     'actualTimeLocal': '2022-08-15 08:14+02:00',
#     'runwayTimeLocal': '2022-08-15 08:14+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:20Z',
#     'actualTimeUtc': '2022-08-15 06:14Z',
#     'runwayTimeUtc': '2022-08-15 06:14Z',
#     'terminal': '2',
#     'baggageBelt': '8',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9560',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:30+02:00',
#     'actualTimeLocal': '2022-08-15 08:22+02:00',
#     'runwayTimeLocal': '2022-08-15 08:22+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:30Z',
#     'actualTimeUtc': '2022-08-15 06:22Z',
#     'runwayTimeUtc': '2022-08-15 06:22Z',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9596',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'EPKK', 'iata': 'KRK', 'name': 'Kraków'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:35+02:00',
#     'actualTimeLocal': '2022-08-15 08:27+02:00',
#     'runwayTimeLocal': '2022-08-15 08:27+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:35Z',
#     'actualTimeUtc': '2022-08-15 06:27Z',
#     'runwayTimeUtc': '2022-08-15 06:27Z',
#     'terminal': '2',
#     'baggageBelt': '13',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9631',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'EGGD', 'iata': 'BRS', 'name': 'Bristol'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:50+02:00',
#     'actualTimeLocal': '2022-08-15 08:25+02:00',
#     'runwayTimeLocal': '2022-08-15 08:25+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:50Z',
#     'actualTimeUtc': '2022-08-15 06:25Z',
#     'runwayTimeUtc': '2022-08-15 06:25Z',
#     'terminal': '2',
#     'baggageBelt': '10',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9422',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:30+02:00',
#     'actualTimeLocal': '2022-08-15 08:13+02:00',
#     'runwayTimeLocal': '2022-08-15 08:13+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:30Z',
#     'actualTimeUtc': '2022-08-15 06:13Z',
#     'runwayTimeUtc': '2022-08-15 06:13Z',
#     'terminal': '2',
#     'baggageBelt': '9',
#     'quality': ['Basic', 'Live']},
#    'number': 'EY 7356',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Etihad Airways'}},
#   {'departure': {'airport': {'icao': 'EGNM', 'iata': 'LBA', 'name': 'Leeds'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:40+02:00',
#     'actualTimeLocal': '2022-08-15 08:22+02:00',
#     'runwayTimeLocal': '2022-08-15 08:22+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:40Z',
#     'actualTimeUtc': '2022-08-15 06:22Z',
#     'runwayTimeUtc': '2022-08-15 06:22Z',
#     'terminal': '2',
#     'baggageBelt': '8',
#     'quality': ['Basic', 'Live']},
#    'number': 'G3 5531',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'Gol'}},
#   {'departure': {'airport': {'icao': 'ENGM', 'iata': 'OSL', 'name': 'Oslo'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:15+02:00',
#     'actualTimeLocal': '2022-08-15 08:02+02:00',
#     'runwayTimeLocal': '2022-08-15 08:02+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:15Z',
#     'actualTimeUtc': '2022-08-15 06:02Z',
#     'runwayTimeUtc': '2022-08-15 06:02Z',
#     'terminal': '2',
#     'baggageBelt': '9',
#     'quality': ['Basic', 'Live']},
#    'number': 'G3 5693',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Gol'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:10+02:00',
#     'actualTimeLocal': '2022-08-15 08:12+02:00',
#     'runwayTimeLocal': '2022-08-15 08:12+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:10Z',
#     'actualTimeUtc': '2022-08-15 06:12Z',
#     'runwayTimeUtc': '2022-08-15 06:12Z',
#     'terminal': '2',
#     'baggageBelt': '13',
#     'quality': ['Basic', 'Live']},
#    'number': 'GA 9083',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'Garuda Indonesia'}},
#   {'departure': {'airport': {'icao': 'EGCC',
#      'iata': 'MAN',
#      'name': 'Manchester'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:15+02:00',
#     'actualTimeLocal': '2022-08-15 08:55+02:00',
#     'runwayTimeLocal': '2022-08-15 08:55+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:15Z',
#     'actualTimeUtc': '2022-08-15 06:55Z',
#     'runwayTimeUtc': '2022-08-15 06:55Z',
#     'terminal': '2',
#     'baggageBelt': '11',
#     'quality': ['Basic', 'Live']},
#    'number': 'GA 9761',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-700 (winglets)'},
#    'airline': {'name': 'Garuda Indonesia'}},
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:40+02:00',
#     'actualTimeLocal': '2022-08-15 08:25+02:00',
#     'runwayTimeLocal': '2022-08-15 08:25+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:40Z',
#     'actualTimeUtc': '2022-08-15 06:25Z',
#     'runwayTimeUtc': '2022-08-15 06:25Z',
#     'terminal': '2',
#     'baggageBelt': '13',
#     'quality': ['Basic', 'Live']},
#    'number': 'GA 9763',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Garuda Indonesia'}},
#   {'departure': {'airport': {'icao': 'LIMC', 'iata': 'MXP', 'name': 'Milan'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:35+02:00',
#     'actualTimeLocal': '2022-08-15 08:06+02:00',
#     'runwayTimeLocal': '2022-08-15 08:06+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:35Z',
#     'actualTimeUtc': '2022-08-15 06:06Z',
#     'runwayTimeUtc': '2022-08-15 06:06Z',
#     'terminal': '2',
#     'baggageBelt': '12',
#     'quality': ['Basic', 'Live']},
#    'number': 'GA 9765',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Garuda Indonesia'}},
#   {'departure': {'airport': {'icao': 'LFML',
#      'iata': 'MRS',
#      'name': 'Marseille'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:55+02:00',
#     'actualTimeLocal': '2022-08-15 08:58+02:00',
#     'runwayTimeLocal': '2022-08-15 08:58+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:55Z',
#     'actualTimeUtc': '2022-08-15 06:58Z',
#     'runwayTimeUtc': '2022-08-15 06:58Z',
#     'terminal': '2',
#     'baggageBelt': '13',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 3597',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'KSLC',
#      'iata': 'SLC',
#      'name': 'Salt Lake City'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:15+02:00',
#     'actualTimeLocal': '2022-08-15 08:15+02:00',
#     'runwayTimeLocal': '2022-08-15 08:15+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:15Z',
#     'actualTimeUtc': '2022-08-15 06:15Z',
#     'runwayTimeUtc': '2022-08-15 06:15Z',
#     'terminal': '3',
#     'baggageBelt': '15',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 6026',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A330-900 NEO'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'KATL', 'iata': 'ATL', 'name': 'Atlanta'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:10+02:00',
#     'actualTimeLocal': '2022-08-15 08:57+02:00',
#     'runwayTimeLocal': '2022-08-15 08:57+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:10Z',
#     'actualTimeUtc': '2022-08-15 06:57Z',
#     'runwayTimeUtc': '2022-08-15 06:57Z',
#     'terminal': '3',
#     'baggageBelt': '16',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 6072',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A330-300'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EGGD', 'iata': 'BRS', 'name': 'Bristol'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:50+02:00',
#     'actualTimeLocal': '2022-08-15 08:25+02:00',
#     'runwayTimeLocal': '2022-08-15 08:25+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:50Z',
#     'actualTimeUtc': '2022-08-15 06:25Z',
#     'runwayTimeUtc': '2022-08-15 06:25Z',
#     'terminal': '2',
#     'baggageBelt': '10',
#     'quality': ['Basic', 'Live']},
#    'number': 'KQ 1046',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'airport': {'icao': 'LFBO',
#      'iata': 'TLS',
#      'name': 'Toulouse-Blagnac'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:20+02:00',
#     'actualTimeLocal': '2022-08-15 08:03+02:00',
#     'runwayTimeLocal': '2022-08-15 08:03+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:20Z',
#     'actualTimeUtc': '2022-08-15 06:03Z',
#     'runwayTimeUtc': '2022-08-15 06:03Z',
#     'terminal': '2',
#     'baggageBelt': '11',
#     'quality': ['Basic', 'Live']},
#    'number': 'KQ 1300',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-700 (winglets)'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:35+02:00',
#     'actualTimeLocal': '2022-08-15 08:21+02:00',
#     'runwayTimeLocal': '2022-08-15 08:21+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:35Z',
#     'actualTimeUtc': '2022-08-15 06:21Z',
#     'runwayTimeUtc': '2022-08-15 06:21Z',
#     'terminal': '2',
#     'baggageBelt': '10',
#     'quality': ['Basic', 'Live']},
#    'number': 'KQ 1952',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'airport': {'icao': 'ENGM', 'iata': 'OSL', 'name': 'Oslo'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:15+02:00',
#     'actualTimeLocal': '2022-08-15 08:02+02:00',
#     'runwayTimeLocal': '2022-08-15 08:02+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:15Z',
#     'actualTimeUtc': '2022-08-15 06:02Z',
#     'runwayTimeUtc': '2022-08-15 06:02Z',
#     'terminal': '2',
#     'baggageBelt': '9',
#     'quality': ['Basic', 'Live']},
#    'number': 'MF 9318',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'airport': {'icao': 'LIRQ', 'iata': 'FLR', 'name': 'Firenze'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:40+02:00',
#     'actualTimeLocal': '2022-08-15 08:24+02:00',
#     'runwayTimeLocal': '2022-08-15 08:24+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:40Z',
#     'actualTimeUtc': '2022-08-15 06:24Z',
#     'runwayTimeUtc': '2022-08-15 06:24Z',
#     'terminal': '2',
#     'baggageBelt': '8',
#     'quality': ['Basic', 'Live']},
#    'number': 'MF 9676',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:10+02:00',
#     'actualTimeLocal': '2022-08-15 08:12+02:00',
#     'runwayTimeLocal': '2022-08-15 08:12+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:10Z',
#     'actualTimeUtc': '2022-08-15 06:12Z',
#     'runwayTimeUtc': '2022-08-15 06:12Z',
#     'terminal': '2',
#     'baggageBelt': '13',
#     'quality': ['Basic', 'Live']},
#    'number': 'MF 9684',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:35+02:00',
#     'actualTimeLocal': '2022-08-15 08:17+02:00',
#     'runwayTimeLocal': '2022-08-15 08:17+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:35Z',
#     'actualTimeUtc': '2022-08-15 06:17Z',
#     'runwayTimeUtc': '2022-08-15 06:17Z',
#     'terminal': '2',
#     'baggageBelt': '12',
#     'quality': ['Basic', 'Live']},
#    'number': 'MK 9390',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Air Mauritius'}},
#   {'departure': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:30+02:00',
#     'actualTimeLocal': '2022-08-15 08:13+02:00',
#     'runwayTimeLocal': '2022-08-15 08:13+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:30Z',
#     'actualTimeUtc': '2022-08-15 06:13Z',
#     'runwayTimeUtc': '2022-08-15 06:13Z',
#     'terminal': '2',
#     'baggageBelt': '9',
#     'quality': ['Basic', 'Live']},
#    'number': 'MU 1566',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'China Eastern'}},
#   {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:20+02:00',
#     'actualTimeLocal': '2022-08-15 08:14+02:00',
#     'runwayTimeLocal': '2022-08-15 08:14+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:20Z',
#     'actualTimeUtc': '2022-08-15 06:14Z',
#     'runwayTimeUtc': '2022-08-15 06:14Z',
#     'terminal': '2',
#     'baggageBelt': '8',
#     'quality': ['Basic', 'Live']},
#    'number': 'MU 1594',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'China Eastern'}},
#   {'departure': {'airport': {'icao': 'EGNM', 'iata': 'LBA', 'name': 'Leeds'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:40+02:00',
#     'actualTimeLocal': '2022-08-15 08:22+02:00',
#     'runwayTimeLocal': '2022-08-15 08:22+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:40Z',
#     'actualTimeUtc': '2022-08-15 06:22Z',
#     'runwayTimeUtc': '2022-08-15 06:22Z',
#     'terminal': '2',
#     'baggageBelt': '8',
#     'quality': ['Basic', 'Live']},
#    'number': 'MU 1634',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'China Eastern'}},
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:40+02:00',
#     'actualTimeLocal': '2022-08-15 08:25+02:00',
#     'runwayTimeLocal': '2022-08-15 08:25+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:40Z',
#     'actualTimeUtc': '2022-08-15 06:25Z',
#     'runwayTimeUtc': '2022-08-15 06:25Z',
#     'terminal': '2',
#     'baggageBelt': '13',
#     'quality': ['Basic', 'Live']},
#    'number': 'MU 1801',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'China Eastern'}},
#   {'departure': {'airport': {'icao': 'EGCC',
#      'iata': 'MAN',
#      'name': 'Manchester'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:15+02:00',
#     'actualTimeLocal': '2022-08-15 08:55+02:00',
#     'runwayTimeLocal': '2022-08-15 08:55+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:15Z',
#     'actualTimeUtc': '2022-08-15 06:55Z',
#     'runwayTimeUtc': '2022-08-15 06:55Z',
#     'terminal': '2',
#     'baggageBelt': '11',
#     'quality': ['Basic', 'Live']},
#    'number': 'PS 9483',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-700 (winglets)'},
#    'airline': {'name': 'UIA'}},
#   {'departure': {'airport': {'icao': 'KLAX',
#      'iata': 'LAX',
#      'name': 'Los Angeles'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:10+02:00',
#     'actualTimeLocal': '2022-08-15 09:03+02:00',
#     'runwayTimeLocal': '2022-08-15 09:03+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:10Z',
#     'actualTimeUtc': '2022-08-15 07:03Z',
#     'runwayTimeUtc': '2022-08-15 07:03Z',
#     'terminal': '4',
#     'baggageBelt': '19',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 8250',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-10'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'airport': {'icao': 'TNCC',
#      'iata': 'CUR',
#      'name': 'Willemstad'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:30+02:00',
#     'actualTimeLocal': '2022-08-15 09:13+02:00',
#     'runwayTimeLocal': '2022-08-15 09:13+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:30Z',
#     'actualTimeUtc': '2022-08-15 07:13Z',
#     'runwayTimeUtc': '2022-08-15 07:13Z',
#     'terminal': '4',
#     'baggageBelt': '22',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 8392',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 777-300ER'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'airport': {'icao': 'SCEL',
#      'iata': 'SCL',
#      'name': 'Santiago'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:40+02:00',
#     'actualTimeLocal': '2022-08-15 09:18+02:00',
#     'runwayTimeLocal': '2022-08-15 09:18+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:40Z',
#     'actualTimeUtc': '2022-08-15 07:18Z',
#     'runwayTimeUtc': '2022-08-15 07:18Z',
#     'terminal': '2',
#     'baggageBelt': '9',
#     'quality': ['Basic', 'Live']},
#    'number': 'AR 7800',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-9'},
#    'airline': {'name': 'Aerolineas Argentinas'}},
#   {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:45+02:00',
#     'actualTimeLocal': '2022-08-15 09:57+02:00',
#     'runwayTimeLocal': '2022-08-15 09:57+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:45Z',
#     'actualTimeUtc': '2022-08-15 07:57Z',
#     'runwayTimeUtc': '2022-08-15 07:57Z',
#     'terminal': '2',
#     'baggageBelt': '11',
#     'quality': ['Basic', 'Live']},
#    'number': 'CI 9292',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321'},
#    'airline': {'name': 'China'}},
#   {'departure': {'airport': {'icao': 'EDDH', 'iata': 'HAM', 'name': 'Hamburg'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:50+02:00',
#     'actualTimeLocal': '2022-08-15 09:59+02:00',
#     'runwayTimeLocal': '2022-08-15 09:59+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:50Z',
#     'actualTimeUtc': '2022-08-15 07:59Z',
#     'runwayTimeUtc': '2022-08-15 07:59Z',
#     'terminal': '2',
#     'baggageBelt': '13',
#     'quality': ['Basic', 'Live']},
#    'number': 'CZ 7655',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'China Southern'}},
#   {'departure': {'airport': {'icao': 'EBBR',
#      'iata': 'BRU',
#      'name': 'Brussels'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:00+02:00',
#     'actualTimeLocal': '2022-08-15 08:35+02:00',
#     'runwayTimeLocal': '2022-08-15 08:35+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:00Z',
#     'actualTimeUtc': '2022-08-15 06:35Z',
#     'runwayTimeUtc': '2022-08-15 06:35Z',
#     'terminal': '2',
#     'baggageBelt': '13',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9425',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:10+02:00',
#     'actualTimeLocal': '2022-08-15 08:48+02:00',
#     'runwayTimeLocal': '2022-08-15 08:48+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:10Z',
#     'actualTimeUtc': '2022-08-15 06:48Z',
#     'runwayTimeUtc': '2022-08-15 06:48Z',
#     'terminal': '2',
#     'baggageBelt': '8',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9440',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'LEBB', 'iata': 'BIO', 'name': 'Bilbao'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:00+02:00',
#     'actualTimeLocal': '2022-08-15 08:36+02:00',
#     'runwayTimeLocal': '2022-08-15 08:36+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:00Z',
#     'actualTimeUtc': '2022-08-15 06:36Z',
#     'runwayTimeUtc': '2022-08-15 06:36Z',
#     'terminal': '2',
#     'baggageBelt': '8',
#     'quality': ['Basic', 'Live']},
#    'number': 'G3 8587',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Gol'}},
#   {'departure': {'airport': {'icao': 'LFRS', 'iata': 'NTE', 'name': 'Nantes'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:10+02:00',
#     'actualTimeLocal': '2022-08-15 08:55+02:00',
#     'runwayTimeLocal': '2022-08-15 08:55+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:10Z',
#     'actualTimeUtc': '2022-08-15 06:55Z',
#     'runwayTimeUtc': '2022-08-15 06:55Z',
#     'terminal': '2',
#     'baggageBelt': '12',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 2032',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'UGTB', 'iata': 'TBS', 'name': 'Tbilisi'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:35+02:00',
#     'actualTimeLocal': '2022-08-15 10:02+02:00',
#     'runwayTimeLocal': '2022-08-15 10:02+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:35Z',
#     'actualTimeUtc': '2022-08-15 08:02Z',
#     'runwayTimeUtc': '2022-08-15 08:02Z',
#     'terminal': '2',
#     'baggageBelt': '12',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 3109',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EDDH', 'iata': 'HAM', 'name': 'Hamburg'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:50+02:00',
#     'actualTimeLocal': '2022-08-15 09:59+02:00',
#     'runwayTimeLocal': '2022-08-15 09:59+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:50Z',
#     'actualTimeUtc': '2022-08-15 07:59Z',
#     'runwayTimeUtc': '2022-08-15 07:59Z',
#     'terminal': '2',
#     'baggageBelt': '13',
#     'quality': ['Basic', 'Live']},
#    'number': 'KQ 1778',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'airport': {'icao': 'EBBR',
#      'iata': 'BRU',
#      'name': 'Brussels'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:00+02:00',
#     'actualTimeLocal': '2022-08-15 08:35+02:00',
#     'runwayTimeLocal': '2022-08-15 08:35+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:00Z',
#     'actualTimeUtc': '2022-08-15 06:35Z',
#     'runwayTimeUtc': '2022-08-15 06:35Z',
#     'terminal': '2',
#     'baggageBelt': '13',
#     'quality': ['Basic', 'Live']},
#    'number': 'MF 9682',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:10+02:00',
#     'actualTimeLocal': '2022-08-15 08:48+02:00',
#     'runwayTimeLocal': '2022-08-15 08:48+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:10Z',
#     'actualTimeUtc': '2022-08-15 06:48Z',
#     'runwayTimeUtc': '2022-08-15 06:48Z',
#     'terminal': '2',
#     'baggageBelt': '8',
#     'quality': ['Basic', 'Live']},
#    'number': 'MF 9692',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:45+02:00',
#     'actualTimeLocal': '2022-08-15 09:57+02:00',
#     'runwayTimeLocal': '2022-08-15 09:57+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:45Z',
#     'actualTimeUtc': '2022-08-15 07:57Z',
#     'runwayTimeUtc': '2022-08-15 07:57Z',
#     'terminal': '2',
#     'baggageBelt': '11',
#     'quality': ['Basic', 'Live']},
#    'number': 'MK 9392',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321'},
#    'airline': {'name': 'Air Mauritius'}},
#   {'departure': {'airport': {'icao': 'OMAA',
#      'iata': 'AUH',
#      'name': 'Abu Dhabi Island and Internal Islands City'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:00+02:00',
#     'actualTimeLocal': '2022-08-15 08:19+02:00',
#     'runwayTimeLocal': '2022-08-15 08:19+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:00Z',
#     'actualTimeUtc': '2022-08-15 06:19Z',
#     'runwayTimeUtc': '2022-08-15 06:19Z',
#     'terminal': '3',
#     'baggageBelt': '18',
#     'quality': ['Basic', 'Live']},
#    'number': 'PK 4077',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-10'},
#    'airline': {'name': 'Pakistan International'}},
#   {'departure': {'airport': {'icao': 'KJFK',
#      'iata': 'JFK',
#      'name': 'New York'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:15+02:00',
#     'actualTimeLocal': '2022-08-15 08:53+02:00',
#     'runwayTimeLocal': '2022-08-15 08:53+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:15Z',
#     'actualTimeUtc': '2022-08-15 06:53Z',
#     'runwayTimeUtc': '2022-08-15 06:53Z',
#     'terminal': '3',
#     'baggageBelt': '15',
#     'quality': ['Basic', 'Live']},
#    'number': 'VS 3938',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A330-900 NEO'},
#    'airline': {'name': 'Virgin Atlantic'}},
#   {'departure': {'airport': {'icao': 'KATL', 'iata': 'ATL', 'name': 'Atlanta'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 10:35+02:00',
#     'actualTimeLocal': '2022-08-15 10:41+02:00',
#     'runwayTimeLocal': '2022-08-15 10:41+02:00',
#     'scheduledTimeUtc': '2022-08-15 08:35Z',
#     'actualTimeUtc': '2022-08-15 08:41Z',
#     'runwayTimeUtc': '2022-08-15 08:41Z',
#     'terminal': '3',
#     'baggageBelt': '15',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 3655',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A350-900'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 10:50+02:00',
#     'actualTimeLocal': '2022-08-15 10:31+02:00',
#     'runwayTimeLocal': '2022-08-15 10:31+02:00',
#     'scheduledTimeUtc': '2022-08-15 08:50Z',
#     'actualTimeUtc': '2022-08-15 08:31Z',
#     'runwayTimeUtc': '2022-08-15 08:31Z',
#     'terminal': '2',
#     'baggageBelt': '12',
#     'quality': ['Basic', 'Live']},
#    'number': 'AZ 3757',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Alitalia'}},
#   {'departure': {'airport': {'icao': 'EGPD',
#      'iata': 'ABZ',
#      'name': 'Aberdeen'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 10:30+02:00',
#     'actualTimeLocal': '2022-08-15 10:17+02:00',
#     'runwayTimeLocal': '2022-08-15 10:17+02:00',
#     'scheduledTimeUtc': '2022-08-15 08:30Z',
#     'actualTimeUtc': '2022-08-15 08:17Z',
#     'runwayTimeUtc': '2022-08-15 08:17Z',
#     'terminal': '2',
#     'baggageBelt': '9',
#     'quality': ['Basic', 'Live']},
#    'number': 'AZ 3795',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 195-E2'},
#    'airline': {'name': 'Alitalia'}},
#   {'departure': {'airport': {'icao': 'EGKK', 'iata': 'LGW', 'name': 'London'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 10:05+02:00',
#     'actualTimeLocal': '2022-08-15 10:05+02:00',
#     'scheduledTimeUtc': '2022-08-15 08:05Z',
#     'actualTimeUtc': '2022-08-15 08:05Z',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 2824',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'British Airways'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 10:55+02:00',
#     'actualTimeLocal': '2022-08-15 10:47+02:00',
#     'runwayTimeLocal': '2022-08-15 10:47+02:00',
#     'scheduledTimeUtc': '2022-08-15 08:55Z',
#     'actualTimeUtc': '2022-08-15 08:47Z',
#     'runwayTimeUtc': '2022-08-15 08:47Z',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 161R',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A330-300'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'EDDB', 'iata': 'BER', 'name': 'Berlin'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 10:40+02:00',
#     'actualTimeLocal': '2022-08-15 10:12+02:00',
#     'runwayTimeLocal': '2022-08-15 10:12+02:00',
#     'scheduledTimeUtc': '2022-08-15 08:40Z',
#     'actualTimeUtc': '2022-08-15 08:12Z',
#     'runwayTimeUtc': '2022-08-15 08:12Z',
#     'terminal': '2',
#     'baggageBelt': '8',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9267',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'FAOR', 'iata': 'JNB', 'name': "Jo'anna"},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 10:15+02:00',
#     'actualTimeLocal': '2022-08-15 10:48+02:00',
#     'runwayTimeLocal': '2022-08-15 10:48+02:00',
#     'scheduledTimeUtc': '2022-08-15 08:15Z',
#     'actualTimeUtc': '2022-08-15 08:48Z',
#     'runwayTimeUtc': '2022-08-15 08:48Z',
#     'terminal': '3',
#     'baggageBelt': '16',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9473',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-9'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 10:50+02:00',
#     'actualTimeLocal': '2022-08-15 10:31+02:00',
#     'runwayTimeLocal': '2022-08-15 10:31+02:00',
#     'scheduledTimeUtc': '2022-08-15 08:50Z',
#     'actualTimeUtc': '2022-08-15 08:31Z',
#     'runwayTimeUtc': '2022-08-15 08:31Z',
#     'terminal': '2',
#     'baggageBelt': '12',
#     'quality': ['Basic', 'Live']},
#    'number': 'G3 5689',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Gol'}},
#   {'departure': {'airport': {'icao': 'LIEO', 'iata': 'OLB', 'name': 'Olbia'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 10:45+02:00',
#     'actualTimeLocal': '2022-08-15 10:49+02:00',
#     'runwayTimeLocal': '2022-08-15 10:49+02:00',
#     'scheduledTimeUtc': '2022-08-15 08:45Z',
#     'actualTimeUtc': '2022-08-15 08:49Z',
#     'runwayTimeUtc': '2022-08-15 08:49Z',
#     'terminal': '1',
#     'baggageBelt': '4',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 2760',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-700 (winglets)'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EGPD',
#      'iata': 'ABZ',
#      'name': 'Aberdeen'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 10:30+02:00',
#     'actualTimeLocal': '2022-08-15 10:17+02:00',
#     'runwayTimeLocal': '2022-08-15 10:17+02:00',
#     'scheduledTimeUtc': '2022-08-15 08:30Z',
#     'actualTimeUtc': '2022-08-15 08:17Z',
#     'runwayTimeUtc': '2022-08-15 08:17Z',
#     'terminal': '2',
#     'baggageBelt': '9',
#     'quality': ['Basic', 'Live']},
#    'number': 'KQ 1444',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 195-E2'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 10:50+02:00',
#     'actualTimeLocal': '2022-08-15 10:31+02:00',
#     'runwayTimeLocal': '2022-08-15 10:31+02:00',
#     'scheduledTimeUtc': '2022-08-15 08:50Z',
#     'actualTimeUtc': '2022-08-15 08:31Z',
#     'runwayTimeUtc': '2022-08-15 08:31Z',
#     'terminal': '2',
#     'baggageBelt': '12',
#     'quality': ['Basic', 'Live']},
#    'number': 'MF 9314',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 10:35+02:00',
#     'actualTimeLocal': '2022-08-15 10:27+02:00',
#     'runwayTimeLocal': '2022-08-15 10:27+02:00',
#     'scheduledTimeUtc': '2022-08-15 08:35Z',
#     'actualTimeUtc': '2022-08-15 08:27Z',
#     'runwayTimeUtc': '2022-08-15 08:27Z',
#     'quality': ['Basic', 'Live']},
#    'number': 'MF 9925R',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 777-300ER'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 11:00+02:00',
#     'actualTimeLocal': '2022-08-15 10:55+02:00',
#     'runwayTimeLocal': '2022-08-15 10:55+02:00',
#     'scheduledTimeUtc': '2022-08-15 09:00Z',
#     'actualTimeUtc': '2022-08-15 08:55Z',
#     'runwayTimeUtc': '2022-08-15 08:55Z',
#     'terminal': '2',
#     'baggageBelt': '10',
#     'quality': ['Basic', 'Live']},
#    'number': 'CZ 7676',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-900 (winglets) '},
#    'airline': {'name': 'China Southern'}},
#   {'departure': {'airport': {'icao': 'EGPF', 'iata': 'GLA', 'name': 'Glasgow'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 11:50+02:00',
#     'actualTimeLocal': '2022-08-15 11:54+02:00',
#     'runwayTimeLocal': '2022-08-15 11:54+02:00',
#     'scheduledTimeUtc': '2022-08-15 09:50Z',
#     'actualTimeUtc': '2022-08-15 09:54Z',
#     'runwayTimeUtc': '2022-08-15 09:54Z',
#     'terminal': '2',
#     'baggageBelt': '12',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9296',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'EBBR',
#      'iata': 'BRU',
#      'name': 'Brussels'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 11:25+02:00',
#     'actualTimeLocal': '2022-08-15 11:59+02:00',
#     'runwayTimeLocal': '2022-08-15 11:59+02:00',
#     'scheduledTimeUtc': '2022-08-15 09:25Z',
#     'actualTimeUtc': '2022-08-15 09:59Z',
#     'runwayTimeUtc': '2022-08-15 09:59Z',
#     'terminal': '2',
#     'baggageBelt': '9',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9426',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'quality': []},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 11:35+02:00',
#     'actualTimeLocal': '2022-08-15 11:34+02:00',
#     'runwayTimeLocal': '2022-08-15 11:34+02:00',
#     'scheduledTimeUtc': '2022-08-15 09:35Z',
#     'actualTimeUtc': '2022-08-15 09:34Z',
#     'runwayTimeUtc': '2022-08-15 09:34Z',
#     'terminal': '2',
#     'baggageBelt': '13',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9430',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'EDDV', 'iata': 'HAJ', 'name': 'Hanover'},
# ...
#     'actualTimeLocal': '2022-08-15 15:37+02:00',
#     'runwayTimeLocal': '2022-08-15 15:37+02:00',
#     'scheduledTimeUtc': '2022-08-15 13:40Z',
#     'actualTimeUtc': '2022-08-15 13:37Z',
#     'runwayTimeUtc': '2022-08-15 13:37Z',
#     'terminal': '3',
#     'baggageBelt': '16',
#     'quality': ['Basic', 'Live']},
#    'number': 'MF 9830',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'airport': {'icao': 'LEIB',
#      'iata': 'IBZ',
#      'name': 'Ibiza Town'},
#     'scheduledTimeLocal': '2022-08-15 09:50+02:00',
#     'actualTimeLocal': '2022-08-15 09:52+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:50Z',
#     'actualTimeUtc': '2022-08-15 07:52Z',
#     'terminal': '1',
#     'checkInDesk': '17-18',
#     'gate': '14',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 12:30+02:00',
#     'actualTimeLocal': '2022-08-15 12:08+02:00',
#     'runwayTimeLocal': '2022-08-15 12:08+02:00',
#     'scheduledTimeUtc': '2022-08-15 10:30Z',
#     'actualTimeUtc': '2022-08-15 10:08Z',
#     'runwayTimeUtc': '2022-08-15 10:08Z',
#     'terminal': '1',
#     'baggageBelt': '6',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 7502',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-700 (winglets)'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTimeLocal': '2022-08-15 07:05+02:00',
#     'actualTimeLocal': '2022-08-15 07:12+02:00',
#     'scheduledTimeUtc': '2022-08-15 05:05Z',
#     'actualTimeUtc': '2022-08-15 05:12Z',
#     'terminal': '2',
#     'checkInDesk': '516-532',
#     'gate': 'E71',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:40+02:00',
#     'actualTimeLocal': '2022-08-15 09:26+02:00',
#     'runwayTimeLocal': '2022-08-15 09:26+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:40Z',
#     'actualTimeUtc': '2022-08-15 07:26Z',
#     'runwayTimeUtc': '2022-08-15 07:26Z',
#     'terminal': '3',
#     'baggageBelt': '17',
#     'quality': ['Basic', 'Live']},
#    'number': 'CI 9231',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-9'},
#    'airline': {'name': 'China'}},
#   {'departure': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTimeLocal': '2022-08-15 07:05+02:00',
#     'actualTimeLocal': '2022-08-15 07:12+02:00',
#     'scheduledTimeUtc': '2022-08-15 05:05Z',
#     'actualTimeUtc': '2022-08-15 05:12Z',
#     'terminal': '2',
#     'checkInDesk': '516-532',
#     'gate': 'E71',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 09:40+02:00',
#     'actualTimeLocal': '2022-08-15 09:26+02:00',
#     'runwayTimeLocal': '2022-08-15 09:26+02:00',
#     'scheduledTimeUtc': '2022-08-15 07:40Z',
#     'actualTimeUtc': '2022-08-15 07:26Z',
#     'runwayTimeUtc': '2022-08-15 07:26Z',
#     'terminal': '3',
#     'baggageBelt': '17',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 3390',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-9'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTimeLocal': '2022-08-15 10:20+02:00',
#     'actualTimeLocal': '2022-08-15 10:22+02:00',
#     'scheduledTimeUtc': '2022-08-15 08:20Z',
#     'actualTimeUtc': '2022-08-15 08:22Z',
#     'terminal': '2',
#     'checkInDesk': '427-431',
#     'gate': 'E83',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 13:00+02:00',
#     'actualTimeLocal': '2022-08-15 12:34+02:00',
#     'runwayTimeLocal': '2022-08-15 12:34+02:00',
#     'scheduledTimeUtc': '2022-08-15 11:00Z',
#     'actualTimeUtc': '2022-08-15 10:34Z',
#     'runwayTimeUtc': '2022-08-15 10:34Z',
#     'terminal': '3',
#     'baggageBelt': '18',
#     'quality': ['Basic', 'Live']},
#    'number': 'EY 5827',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Etihad Airways'}},
#   {'departure': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTimeLocal': '2022-08-15 12:50+02:00',
#     'actualTimeLocal': '2022-08-15 12:50+02:00',
#     'scheduledTimeUtc': '2022-08-15 10:50Z',
#     'actualTimeUtc': '2022-08-15 10:50Z',
#     'terminal': '2',
#     'checkInDesk': '427-431',
#     'gate': 'E81',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 15:20+02:00',
#     'actualTimeLocal': '2022-08-15 15:22+02:00',
#     'runwayTimeLocal': '2022-08-15 15:22+02:00',
#     'scheduledTimeUtc': '2022-08-15 13:20Z',
#     'actualTimeUtc': '2022-08-15 13:22Z',
#     'runwayTimeUtc': '2022-08-15 13:22Z',
#     'terminal': '3',
#     'baggageBelt': '18',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9520',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTimeLocal': '2022-08-15 12:50+02:00',
#     'actualTimeLocal': '2022-08-15 12:50+02:00',
#     'scheduledTimeUtc': '2022-08-15 10:50Z',
#     'actualTimeUtc': '2022-08-15 10:50Z',
#     'terminal': '2',
#     'checkInDesk': '427-431',
#     'gate': 'E81',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 15:20+02:00',
#     'actualTimeLocal': '2022-08-15 15:22+02:00',
#     'runwayTimeLocal': '2022-08-15 15:22+02:00',
#     'scheduledTimeUtc': '2022-08-15 13:20Z',
#     'actualTimeUtc': '2022-08-15 13:22Z',
#     'runwayTimeUtc': '2022-08-15 13:22Z',
#     'terminal': '3',
#     'baggageBelt': '18',
#     'quality': ['Basic', 'Live']},
#    'number': 'KQ 1702',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTimeLocal': '2022-08-15 15:00+02:00',
#     'actualTimeLocal': '2022-08-15 14:59+02:00',
#     'scheduledTimeUtc': '2022-08-15 13:00Z',
#     'actualTimeUtc': '2022-08-15 12:59Z',
#     'terminal': '2',
#     'checkInDesk': '505-532',
#     'gate': 'E82',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 17:35+02:00',
#     'actualTimeLocal': '2022-08-15 17:18+02:00',
#     'runwayTimeLocal': '2022-08-15 17:18+02:00',
#     'scheduledTimeUtc': '2022-08-15 15:35Z',
#     'actualTimeUtc': '2022-08-15 15:18Z',
#     'runwayTimeUtc': '2022-08-15 15:18Z',
#     'terminal': '3',
#     'baggageBelt': '17',
#     'quality': ['Basic', 'Live']},
#    'number': 'GA 9467',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Garuda Indonesia'}},
#   {'departure': {'airport': {'icao': 'LEMG', 'iata': 'AGP', 'name': 'Málaga'},
#     'scheduledTimeLocal': '2022-08-15 08:40+02:00',
#     'actualTimeLocal': '2022-08-15 08:36+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:40Z',
#     'actualTimeUtc': '2022-08-15 06:36Z',
#     'terminal': 'PAX',
#     'checkInDesk': '255-261',
#     'gate': 'D44',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 11:45+02:00',
#     'actualTimeLocal': '2022-08-15 11:21+02:00',
#     'runwayTimeLocal': '2022-08-15 11:21+02:00',
#     'scheduledTimeUtc': '2022-08-15 09:45Z',
#     'actualTimeUtc': '2022-08-15 09:21Z',
#     'runwayTimeUtc': '2022-08-15 09:21Z',
#     'terminal': '3',
#     'baggageBelt': '18',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 7958',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321-200 (Sharklets)'},
#    'airline': {'name': 'EasyJet Europe'}},
#   {'departure': {'airport': {'icao': 'LEMG', 'iata': 'AGP', 'name': 'Málaga'},
#     'scheduledTimeLocal': '2022-08-15 08:40+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:40Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 11:45+02:00',
#     'scheduledTimeUtc': '2022-08-15 09:45Z',
#     'quality': ['Basic']},
#    'number': 'U2 7958',
#    'status': 'CanceledUncertain',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   {'departure': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTimeLocal': '2022-08-15 08:10+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:10Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 10:40+02:00',
#     'actualTimeLocal': '2022-08-15 10:43+02:00',
#     'runwayTimeLocal': '2022-08-15 10:43+02:00',
#     'scheduledTimeUtc': '2022-08-15 08:40Z',
#     'actualTimeUtc': '2022-08-15 08:43Z',
#     'runwayTimeUtc': '2022-08-15 08:43Z',
#     'terminal': '1',
#     'baggageBelt': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'HV 5626',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Transavia'}},
#   {'departure': {'airport': {'icao': 'LGIR',
#      'iata': 'HER',
#      'name': 'Heraklion'},
#     'scheduledTimeLocal': '2022-08-15 10:30+03:00',
#     'scheduledTimeUtc': '2022-08-15 07:30Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 13:20+02:00',
#     'actualTimeLocal': '2022-08-15 13:11+02:00',
#     'runwayTimeLocal': '2022-08-15 13:11+02:00',
#     'scheduledTimeUtc': '2022-08-15 11:20Z',
#     'actualTimeUtc': '2022-08-15 11:11Z',
#     'runwayTimeUtc': '2022-08-15 11:11Z',
#     'terminal': '1',
#     'baggageBelt': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'HV 6920',
#    'callSign': 'TRA6920',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-HSM',
#     'modeS': '485123',
#     'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Transavia'}},
#   {'departure': {'airport': {'icao': 'LGKV', 'iata': 'KVA', 'name': 'Kavala'},
#     'scheduledTimeLocal': '2022-08-15 13:25+03:00',
#     'scheduledTimeUtc': '2022-08-15 10:25Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 15:35+02:00',
#     'actualTimeLocal': '2022-08-15 15:16+02:00',
#     'runwayTimeLocal': '2022-08-15 15:16+02:00',
#     'scheduledTimeUtc': '2022-08-15 13:35Z',
#     'actualTimeUtc': '2022-08-15 13:16Z',
#     'runwayTimeUtc': '2022-08-15 13:16Z',
#     'terminal': '4',
#     'baggageBelt': '22',
#     'quality': ['Basic', 'Live']},
#    'number': 'OR 1153',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'TUIfly Netherlands'}},
#   {'departure': {'airport': {'icao': 'LGSM',
#      'iata': 'SMI',
#      'name': 'Samos Island'},
#     'scheduledTimeLocal': '2022-08-15 10:35+03:00',
#     'scheduledTimeUtc': '2022-08-15 07:35Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 13:15+02:00',
#     'actualTimeLocal': '2022-08-15 13:37+02:00',
#     'runwayTimeLocal': '2022-08-15 13:37+02:00',
#     'scheduledTimeUtc': '2022-08-15 11:15Z',
#     'actualTimeUtc': '2022-08-15 11:37Z',
#     'runwayTimeUtc': '2022-08-15 11:37Z',
#     'terminal': '3',
#     'baggageBelt': '17',
#     'quality': ['Basic', 'Live']},
#    'number': 'HV 5696',
#    'callSign': 'TRA5696',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-HXO',
#     'modeS': '48597E',
#     'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Transavia'}},
#   {'departure': {'airport': {'icao': 'LGZA',
#      'iata': 'ZTH',
#      'name': 'Zakynthos Island'},
#     'scheduledTimeLocal': '2022-08-15 09:55+03:00',
#     'scheduledTimeUtc': '2022-08-15 06:55Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 12:15+02:00',
#     'actualTimeLocal': '2022-08-15 11:57+02:00',
#     'runwayTimeLocal': '2022-08-15 11:57+02:00',
#     'scheduledTimeUtc': '2022-08-15 10:15Z',
#     'actualTimeUtc': '2022-08-15 09:57Z',
#     'runwayTimeUtc': '2022-08-15 09:57Z',
#     'terminal': '1',
#     'baggageBelt': '4',
#     'quality': ['Basic', 'Live']},
#    'number': 'HV 5092',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Transavia'}},
#   {'departure': {'airport': {'icao': 'LHBP',
#      'iata': 'BUD',
#      'name': 'Budapest'},
#     'scheduledTimeLocal': '2022-08-15 06:35+02:00',
#     'actualTimeLocal': '2022-08-15 06:41+02:00',
#     'scheduledTimeUtc': '2022-08-15 04:35Z',
#     'actualTimeUtc': '2022-08-15 04:41Z',
#     'terminal': '2A',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:40+02:00',
#     'actualTimeLocal': '2022-08-15 08:22+02:00',
#     'runwayTimeLocal': '2022-08-15 08:22+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:40Z',
#     'actualTimeUtc': '2022-08-15 06:22Z',
#     'runwayTimeUtc': '2022-08-15 06:22Z',
#     'terminal': '2',
#     'baggageBelt': '9',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 9694',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'LHBP',
#      'iata': 'BUD',
#      'name': 'Budapest'},
#     'scheduledTimeLocal': '2022-08-15 11:20+02:00',
#     'actualTimeLocal': '2022-08-15 11:46+02:00',
#     'scheduledTimeUtc': '2022-08-15 09:20Z',
#     'actualTimeUtc': '2022-08-15 09:46Z',
#     'terminal': '2A',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 13:25+02:00',
#     'actualTimeLocal': '2022-08-15 13:20+02:00',
#     'runwayTimeLocal': '2022-08-15 13:20+02:00',
#     'scheduledTimeUtc': '2022-08-15 11:25Z',
#     'actualTimeUtc': '2022-08-15 11:20Z',
#     'runwayTimeUtc': '2022-08-15 11:20Z',
#     'terminal': '2',
#     'baggageBelt': '12',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1974',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'LICC', 'iata': 'CTA', 'name': 'Catania'},
#     'scheduledTimeLocal': '2022-08-15 10:05+02:00',
#     'actualTimeLocal': '2022-08-15 10:32+02:00',
#     'scheduledTimeUtc': '2022-08-15 08:05Z',
#     'actualTimeUtc': '2022-08-15 08:32Z',
#     'terminal': 'A',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 13:15+02:00',
#     'actualTimeLocal': '2022-08-15 13:05+02:00',
#     'runwayTimeLocal': '2022-08-15 13:05+02:00',
#     'scheduledTimeUtc': '2022-08-15 11:15Z',
#     'actualTimeUtc': '2022-08-15 11:05Z',
#     'runwayTimeUtc': '2022-08-15 11:05Z',
#     'terminal': '1',
#     'baggageBelt': '6',
#     'quality': ['Basic', 'Live']},
#    'number': 'HV 5216',
#    'callSign': 'TRA5216',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LY-DUE',
#     'modeS': '503D3E',
#     'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Transavia'}},
#   {'departure': {'airport': {'icao': 'LIMC', 'iata': 'MXP', 'name': 'Milan'},
#     'scheduledTimeLocal': '2022-08-15 06:10+02:00',
#     'scheduledTimeUtc': '2022-08-15 04:10Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-08-15 08:05+02:00',
#     'scheduledTimeUtc': '2022-08-15 06:05Z',
#     'quality': ['Basic']},
#    'number': 'U2 2723',
#    'status': 'CanceledUncertain',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet'}},
#   ...]}
