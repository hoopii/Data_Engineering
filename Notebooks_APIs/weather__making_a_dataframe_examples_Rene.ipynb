# %% [markdown]
# We've included 2 solutions here. There are also many other ways of formatting this data. Don't wory if you haven't done it exactly like we have.... this is just guide and not a bible.

# %%
import pandas as pd
import requests
from datetime import datetime
import pytz

# %% [markdown]
# # Solution using a for loop

# %% [markdown]
# First we need to take a look at the JSON so we know what we're dealing with.
# - We can view what the JSON contains by checking out the [documentation on the OWM website](https://openweathermap.org/forecast5)
# - Or this can be done manually, like below:

# %%
city = 'Berlin'
API_key = '4fe53ee5e34a7d900ed58bd74bbbb0b7'

# check out the docs for more info on making an api call https://openweathermap.org/forecast5
url = (f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_key}&units=metric")

response = requests.get(url)
json = response.json()

json
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1660986000,
#    'main': {'temp': 19.97,
#     'feels_like': 20.37,
#     'temp_min': 18.71,
#     'temp_max': 19.97,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1009,
#     'humidity': 90,
#     'temp_kf': 1.26},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 3.07, 'deg': 309, 'gust': 7.01},
#    'visibility': 10000,
#    'pop': 0.36,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-20 09:00:00'},
#   {'dt': 1660996800,
#    'main': {'temp': 19.78,
#     'feels_like': 20.09,
#     'temp_min': 19.39,
#     'temp_max': 19.78,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1010,
#     'humidity': 87,
#     'temp_kf': 0.39},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 47},
#    'wind': {'speed': 1.49, 'deg': 282, 'gust': 3.15},
#    'visibility': 10000,
#    'pop': 0.42,
#    'rain': {'3h': 0.17},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-20 12:00:00'},
#   {'dt': 1661007600,
#    'main': {'temp': 19.24,
#     'feels_like': 19.52,
#     'temp_min': 18.87,
#     'temp_max': 19.24,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1010,
#     'humidity': 88,
#     'temp_kf': 0.37},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 0.78, 'deg': 268, 'gust': 1.72},
#    'visibility': 10000,
#    'pop': 0.91,
#    'rain': {'3h': 5.54},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-20 15:00:00'},
#   {'dt': 1661018400,
#    'main': {'temp': 19.11,
#     'feels_like': 19.37,
#     'temp_min': 19.11,
#     'temp_max': 19.11,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.43, 'deg': 191, 'gust': 2.04},
#    'visibility': 10000,
#    'pop': 0.95,
#    'rain': {'3h': 0.11},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-20 18:00:00'},
#   {'dt': 1661029200,
#    'main': {'temp': 18.66,
#     'feels_like': 18.93,
#     'temp_min': 18.66,
#     'temp_max': 18.66,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.37, 'deg': 235, 'gust': 2.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-20 21:00:00'},
#   {'dt': 1661040000,
#    'main': {'temp': 17.62,
#     'feels_like': 17.84,
#     'temp_min': 17.62,
#     'temp_max': 17.62,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.15, 'deg': 309, 'gust': 3.89},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.2},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-21 00:00:00'},
#   {'dt': 1661050800,
#    'main': {'temp': 17.04,
#     'feels_like': 17.2,
#     'temp_min': 17.04,
#     'temp_max': 17.04,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.96, 'deg': 330, 'gust': 3.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-21 03:00:00'},
#   {'dt': 1661061600,
#    'main': {'temp': 17.61,
#     'feels_like': 17.41,
#     'temp_min': 17.61,
#     'temp_max': 17.61,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1010,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.03, 'deg': 316, 'gust': 3.54},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-21 06:00:00'},
#   {'dt': 1661072400,
#    'main': {'temp': 22.57,
#     'feels_like': 22.08,
#     'temp_min': 22.57,
#     'temp_max': 22.57,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.56, 'deg': 317, 'gust': 3.82},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-21 09:00:00'},
#   {'dt': 1661083200,
#    'main': {'temp': 26.05,
#     'feels_like': 26.05,
#     'temp_min': 26.05,
#     'temp_max': 26.05,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 35,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 82},
#    'wind': {'speed': 2.45, 'deg': 306, 'gust': 3.74},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-21 12:00:00'},
#   {'dt': 1661094000,
#    'main': {'temp': 26.6,
#     'feels_like': 26.6,
#     'temp_min': 26.6,
#     'temp_max': 26.6,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1009,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 52},
#    'wind': {'speed': 2.96, 'deg': 294, 'gust': 3.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-21 15:00:00'},
#   {'dt': 1661104800,
#    'main': {'temp': 23.62,
#     'feels_like': 23.11,
#     'temp_min': 23.62,
#     'temp_max': 23.62,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1009,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 65},
#    'wind': {'speed': 2.35, 'deg': 306, 'gust': 4.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-21 18:00:00'},
#   {'dt': 1661115600,
#    'main': {'temp': 20.6,
#     'feels_like': 19.97,
#     'temp_min': 20.6,
#     'temp_max': 20.6,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 41},
#    'wind': {'speed': 1.55, 'deg': 351, 'gust': 2.14},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-21 21:00:00'},
#   {'dt': 1661126400,
#    'main': {'temp': 18.98,
#     'feels_like': 18.32,
#     'temp_min': 18.98,
#     'temp_max': 18.98,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 33},
#    'wind': {'speed': 1.6, 'deg': 24, 'gust': 2.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-22 00:00:00'},
#   {'dt': 1661137200,
#    'main': {'temp': 17.87,
#     'feels_like': 17.23,
#     'temp_min': 17.87,
#     'temp_max': 17.87,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 57},
#    'wind': {'speed': 1.29, 'deg': 342, 'gust': 1.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-22 03:00:00'},
#   {'dt': 1661148000,
#    'main': {'temp': 19.65,
#     'feels_like': 19.05,
#     'temp_min': 19.65,
#     'temp_max': 19.65,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 72},
#    'wind': {'speed': 1.35, 'deg': 57, 'gust': 1.97},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-22 06:00:00'},
#   {'dt': 1661158800,
#    'main': {'temp': 24.36,
#     'feels_like': 23.9,
#     'temp_min': 24.36,
#     'temp_max': 24.36,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.15, 'deg': 101, 'gust': 2.36},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-22 09:00:00'},
#   {'dt': 1661169600,
#    'main': {'temp': 26.26,
#     'feels_like': 26.26,
#     'temp_min': 26.26,
#     'temp_max': 26.26,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 35,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.04, 'deg': 121, 'gust': 2.05},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-22 12:00:00'},
#   {'dt': 1661180400,
#    'main': {'temp': 24.76,
#     'feels_like': 24.36,
#     'temp_min': 24.76,
#     'temp_max': 24.76,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.25, 'deg': 127, 'gust': 3.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-22 15:00:00'},
#   {'dt': 1661191200,
#    'main': {'temp': 20.82,
#     'feels_like': 20.47,
#     'temp_min': 20.82,
#     'temp_max': 20.82,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.33, 'deg': 156, 'gust': 8.1},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-22 18:00:00'},
#   {'dt': 1661202000,
#    'main': {'temp': 17.67,
#     'feels_like': 17.24,
#     'temp_min': 17.67,
#     'temp_max': 17.67,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1012,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.96, 'deg': 144, 'gust': 7.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-22 21:00:00'},
#   {'dt': 1661212800,
#    'main': {'temp': 16.69,
#     'feels_like': 16.43,
#     'temp_min': 16.69,
#     'temp_max': 16.69,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.24, 'deg': 121, 'gust': 4.34},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-23 00:00:00'},
#   {'dt': 1661223600,
#    'main': {'temp': 16.16,
#     'feels_like': 16,
#     'temp_min': 16.16,
#     'temp_max': 16.16,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1012,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.4, 'deg': 109, 'gust': 4.26},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-23 03:00:00'},
#   {'dt': 1661234400,
#    'main': {'temp': 17.51,
#     'feels_like': 17.38,
#     'temp_min': 17.51,
#     'temp_max': 17.51,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 2.5, 'deg': 96, 'gust': 4.52},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-23 06:00:00'},
#   {'dt': 1661245200,
#    'main': {'temp': 21.57,
#     'feels_like': 21.24,
#     'temp_min': 21.57,
#     'temp_max': 21.57,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 44},
#    'wind': {'speed': 2.71, 'deg': 73, 'gust': 3.29},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-23 09:00:00'},
#   {'dt': 1661256000,
#    'main': {'temp': 24.49,
#     'feels_like': 24.12,
#     'temp_min': 24.49,
#     'temp_max': 24.49,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 57},
#    'wind': {'speed': 2.87, 'deg': 62, 'gust': 3.64},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-23 12:00:00'},
#   {'dt': 1661266800,
#    'main': {'temp': 25.35,
#     'feels_like': 25.01,
#     'temp_min': 25.35,
#     'temp_max': 25.35,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 3.36, 'deg': 63, 'gust': 3.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-23 15:00:00'},
#   {'dt': 1661277600,
#    'main': {'temp': 20.99,
#     'feels_like': 20.79,
#     'temp_min': 20.99,
#     'temp_max': 20.99,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1014,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 52},
#    'wind': {'speed': 3.56, 'deg': 88, 'gust': 4.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-23 18:00:00'},
#   {'dt': 1661288400,
#    'main': {'temp': 18.38,
#     'feels_like': 18.28,
#     'temp_min': 18.38,
#     'temp_max': 18.38,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1015,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 3.29, 'deg': 81, 'gust': 6.06},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-23 21:00:00'},
#   {'dt': 1661299200,
#    'main': {'temp': 16.9,
#     'feels_like': 16.84,
#     'temp_min': 16.9,
#     'temp_max': 16.9,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1015,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 2.26, 'deg': 67, 'gust': 4.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-24 00:00:00'},
#   {'dt': 1661310000,
#    'main': {'temp': 16.11,
#     'feels_like': 16.1,
#     'temp_min': 16.11,
#     'temp_max': 16.11,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1015,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.25, 'deg': 54, 'gust': 4.3},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-24 03:00:00'},
#   {'dt': 1661320800,
#    'main': {'temp': 17.86,
#     'feels_like': 17.82,
#     'temp_min': 17.86,
#     'temp_max': 17.86,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1016,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 2.23, 'deg': 44, 'gust': 3.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-24 06:00:00'},
#   {'dt': 1661331600,
#    'main': {'temp': 22.51,
#     'feels_like': 22.41,
#     'temp_min': 22.51,
#     'temp_max': 22.51,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1016,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 31},
#    'wind': {'speed': 3.11, 'deg': 61, 'gust': 3.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-24 09:00:00'},
#   {'dt': 1661342400,
#    'main': {'temp': 25.1,
#     'feels_like': 25,
#     'temp_min': 25.1,
#     'temp_max': 25.1,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1015,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 46},
#    'wind': {'speed': 3.28, 'deg': 58, 'gust': 3.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-24 12:00:00'},
#   {'dt': 1661353200,
#    'main': {'temp': 24.47,
#     'feels_like': 24.36,
#     'temp_min': 24.47,
#     'temp_max': 24.47,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1015,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 83},
#    'wind': {'speed': 3.09, 'deg': 62, 'gust': 3.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-24 15:00:00'},
#   {'dt': 1661364000,
#    'main': {'temp': 23.1,
#     'feels_like': 23.03,
#     'temp_min': 23.1,
#     'temp_max': 23.1,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1015,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 2.54, 'deg': 50, 'gust': 4.54},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-24 18:00:00'},
#   {'dt': 1661374800,
#    'main': {'temp': 21.85,
#     'feels_like': 21.92,
#     'temp_min': 21.85,
#     'temp_max': 21.85,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1015,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.04, 'deg': 50, 'gust': 5.89},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-24 21:00:00'},
#   {'dt': 1661385600,
#    'main': {'temp': 20.89,
#     'feels_like': 20.99,
#     'temp_min': 20.89,
#     'temp_max': 20.89,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1015,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.13, 'deg': 62, 'gust': 5.96},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-25 00:00:00'},
#   {'dt': 1661396400,
#    'main': {'temp': 20.42,
#     'feels_like': 20.55,
#     'temp_min': 20.42,
#     'temp_max': 20.42,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.79, 'deg': 55, 'gust': 5.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-25 03:00:00'},
#   {'dt': 1661407200,
#    'main': {'temp': 20.41,
#     'feels_like': 20.62,
#     'temp_min': 20.41,
#     'temp_max': 20.41,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.69, 'deg': 67, 'gust': 5.39},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-25 06:00:00'}],
#  'city': {'id': 2950159,
#   'name': 'Berlin',
#   'coord': {'lat': 52.5244, 'lon': 13.4105},
#   'country': 'DE',
#   'population': 1000000,
#   'timezone': 7200,
#   'sunrise': 1660967821,
#   'sunset': 1661019776}}

# %% [markdown]
# Now we've discovered what information we have to work with. Let's decide what we want to keep and what we wish to lose.
#
# I feel that from json['list'] it would be good to keep
# - 'weather.main', 'weather.description', 'dt_txt', 'main.temp', 'main.feels_like' 'clouds.all', 'rain.3h', 'snow.3h' 'wind.speed', 'wind.deg', 'main.humidity', 'main.pressure'.
#
# And from json['city'] it would be good to keep
# - 'name' and 'country.
#
# Just to make sure that we got the right place. And as an added extra we'll also include the time that API call was made, so we know how up to date our forecast is.

# %% [markdown]
# **Optional:** let's get a timestamp of when we get the data. Datetime uses the uses the current time of the system, which on local computers is normally correct. But as we're in the cloud, computers are not always in our country, and we therefore add on the timezone module to ensure that our timestamp is local to us and not the computer.

# %%
tz = pytz.timezone('Europe/Berlin')
now = datetime.now().astimezone(tz)

now
# Out:
# datetime.datetime(2022, 8, 27, 13, 43, 55, 5676, tzinfo=<DstTzInfo 'Europe/Berlin' CEST+2:00:00 DST>)

# %% [markdown]
# **Next** let's loop through the json['list'] information get the weather information

# %%
# we'll store the information in this dicitonary:
weather_dict = {'city': [],
                'country': [],
                'forecast_time': [],
                'outlook': [],
                'detailed_outlook': [],
                'temperature': [],
                'temperature_feels_like': [],
                'clouds': [],
                'rain': [],
                'snow': [],
                'wind_speed': [],
                'wind_deg': [],
                'humidity': [],
                'pressure': []}
                #'information_retrieved_at': []}

# let's begin the loop
for i in json['list']:
  weather_dict['city'].append(json['city']['name'])
  weather_dict['country'].append(json['city']['country'])
  weather_dict['forecast_time'].append(i['dt_txt'])
  weather_dict['outlook'].append(i['weather'][0]['main'])
  weather_dict['detailed_outlook'].append(i['weather'][0]['description'])
  weather_dict['temperature'].append(i['main']['temp'])
  weather_dict['temperature_feels_like'].append(i['main']['feels_like'])
  weather_dict['clouds'].append(i['clouds']['all'])
  # sometimes the data is missing for rain and snow. As it is not always raining or snowing
  # we cannot make a DataFrame unless the lists are all the same length, therefore missing values are bad
  # here we say try to append a value if there is one. If not, append a 0
  try:
      weather_dict['rain'].append(i['rain']['3h'])
  except:
      weather_dict['rain'].append('0')
  try:
      weather_dict['snow'].append(i['snow']['3h'])
  except:
      weather_dict['snow'].append('0')
  weather_dict['wind_speed'].append(i['wind']['speed'])
  weather_dict['wind_deg'].append(i['wind']['deg'])
  weather_dict['humidity'].append(i['main']['humidity'])
  weather_dict['pressure'].append(i['main']['pressure'])
  #weather_dict['information_retrieved_at'].append(now.strftime("%d/%m/%Y %H:%M:%S"))

# %% [markdown]
# **Now** we convert our dictionary to a DataFrame

# %%
weather_from_dict_df = pd.DataFrame(weather_dict)

weather_from_dict_df.head()
# Out:
#      city country        forecast_time outlook detailed_outlook  temperature  \
# 0  Berlin      DE  2022-08-27 09:00:00    Rain       light rain        20.06
# 1  Berlin      DE  2022-08-27 12:00:00    Rain    moderate rain        21.12
# 2  Berlin      DE  2022-08-27 15:00:00    Rain       light rain        21.39
# 3  Berlin      DE  2022-08-27 18:00:00    Rain       light rain        19.55
# 4  Berlin      DE  2022-08-27 21:00:00    Rain       light rain        18.87
#
#    temperature_feels_like  clouds  rain snow  wind_speed  wind_deg  humidity  \
# 0                   20.58     100  0.37    0        3.74       318        94
# 1                   21.56      96  4.61    0        4.38       295        87
# 2                   21.73      97  2.37    0        4.85       297        82
# 3                   19.96      97  1.62    0        3.90       320        92
# 4                   19.24     100  1.02    0        3.40       316        93
#
#    pressure
# 0      1009
# 1      1010
# 2      1011
# 3      1012
# 4      1013

# %% [markdown]
# **As a final step**, to keep everything tidy: let's bring everything we did together in a function. And allow the function to take a list of cities as an input

# %%
def get_weather_loop(cities):

  API_key = '4fe53ee5e34a7d900ed58bd74bbbb0b7'

  tz = pytz.timezone('Europe/Berlin')
  now = datetime.now().astimezone(tz)

  weather_dict = {'city': [], 
                'forecast_time': [],
                'outlook': [],
                'detailed_outlook': [],
                'temperature': [],
                'temperature_feels_like': [],
                'clouds': [],
                'rain': [],
                'snow': [],
                'wind_speed': [],
                'wind_deg': [],
                'humidity': [],
                'pressure': [],
                'information_retrieved_at': []}

  for city in cities:
    url = (f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_key}&units=metric")
    response = requests.get(url)
    json = response.json()

    for i in json['list']:
      weather_dict['city'].append(json['city']['name'])
      weather_dict['country'].append(json['city']['country'])
      weather_dict['forecast_time'].append(i['dt_txt'])
      weather_dict['outlook'].append(i['weather'][0]['main'])
      weather_dict['detailed_outlook'].append(i['weather'][0]['description'])
      weather_dict['temperature'].append(i['main']['temp'])
      weather_dict['temperature_feels_like'].append(i['main']['feels_like'])
      weather_dict['clouds'].append(i['clouds']['all'])
      try:
          weather_dict['rain'].append(i['rain']['3h'])
      except:
          weather_dict['rain'].append('0')
      try:
          weather_dict['snow'].append(i['snow']['3h'])
      except:
          weather_dict['snow'].append('0')
      weather_dict['wind_speed'].append(i['wind']['speed'])
      weather_dict['wind_deg'].append(i['wind']['deg'])
      weather_dict['humidity'].append(i['main']['humidity'])
      weather_dict['pressure'].append(i['main']['pressure'])
      weather_dict['information_retrieved_at'].append(now.strftime("%d/%m/%Y %H:%M:%S"))

  return pd.DataFrame(weather_dict)

# %%
json['list']['wind']['speed']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6472/4097819426.py in <module>
# ----> 1 json['list']['wind']['speed']
#
# TypeError: list indices must be integers or slices, not str

# %%
get_weather_loop(['Berlin', 'London'])
# Out:
#       city country        forecast_time outlook detailed_outlook  temperature  \
# 0   Berlin      DE  2022-08-20 09:00:00  Clouds       few clouds        19.97
# 1   Berlin      DE  2022-08-20 12:00:00    Rain       light rain        19.78
# 2   Berlin      DE  2022-08-20 15:00:00    Rain    moderate rain        19.24
# 3   Berlin      DE  2022-08-20 18:00:00    Rain       light rain        19.11
# 4   Berlin      DE  2022-08-20 21:00:00  Clouds  overcast clouds        18.66
# ..     ...     ...                  ...     ...              ...          ...
# 75  London      GB  2022-08-24 18:00:00  Clouds  overcast clouds        27.17
# 76  London      GB  2022-08-24 21:00:00    Rain       light rain        23.53
# 77  London      GB  2022-08-25 00:00:00    Rain    moderate rain        19.68
# 78  London      GB  2022-08-25 03:00:00    Rain    moderate rain        18.53
# 79  London      GB  2022-08-25 06:00:00    Rain    moderate rain        17.15
#
#     temperature_feels_like  clouds  rain snow  wind_speed  wind_deg  humidity  \
# 0                    20.37      20     0    0        3.07       309        90
# 1                    20.09      47  0.17    0        1.49       282        87
# 2                    19.52      73  5.54    0        0.78       268        88
# 3                    19.37     100  0.11    0        1.43       191        88
# 4                    18.93     100     0    0        1.37       235        90
# ..                     ...     ...   ...  ...         ...       ...       ...
# 75                   27.52      95     0    0        2.23       213        49
# 76                   23.64      77  0.42    0        1.68       213        65
# 77                   20.16      89  8.32    0        1.47        14        94
# 78                   18.89      97  3.84    0        3.64       317        94
# 79                   17.32      99  3.91    0        3.89       324        92
#
#     pressure information_retrieved_at
# 0       1010      20/08/2022 09:28:10
# 1       1012      20/08/2022 09:28:10
# 2       1013      20/08/2022 09:28:10
# 3       1015      20/08/2022 09:28:10
# 4       1015      20/08/2022 09:28:10
# ..       ...                      ...
# 75      1013      20/08/2022 09:28:10
# 76      1014      20/08/2022 09:28:10
# 77      1013      20/08/2022 09:28:10
# 78      1013      20/08/2022 09:28:10
# 79      1014      20/08/2022 09:28:10
#
# [80 rows x 15 columns]

# %%
weather_data = get_weather_loop (['Berlin', 'Frankfurt', 'Hamburg', 'Paris', 'Brussels', 'Moscow', 'Stockholm', 'Madrid', 'Barcelona'])

# %%
weather_data.head()
# Out:
#      city country        forecast_time outlook detailed_outlook  temperature  \
# 0  Berlin      DE  2022-08-20 09:00:00  Clouds       few clouds        19.97
# 1  Berlin      DE  2022-08-20 12:00:00    Rain       light rain        19.78
# 2  Berlin      DE  2022-08-20 15:00:00    Rain    moderate rain        19.24
# 3  Berlin      DE  2022-08-20 18:00:00    Rain       light rain        19.11
# 4  Berlin      DE  2022-08-20 21:00:00  Clouds  overcast clouds        18.66
#
#    temperature_feels_like  clouds  rain snow  wind_speed  wind_deg  humidity  \
# 0                   20.37      20     0    0        3.07       309        90
# 1                   20.09      47  0.17    0        1.49       282        87
# 2                   19.52      73  5.54    0        0.78       268        88
# 3                   19.37     100  0.11    0        1.43       191        88
# 4                   18.93     100     0    0        1.37       235        90
#
#    pressure information_retrieved_at
# 0      1010      20/08/2022 09:28:10
# 1      1012      20/08/2022 09:28:10
# 2      1013      20/08/2022 09:28:10
# 3      1015      20/08/2022 09:28:10
# 4      1015      20/08/2022 09:28:10

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   city                      360 non-null    object
#  1   country                   360 non-null    object
#  2   forecast_time             360 non-null    object
#  3   outlook                   360 non-null    object
#  4   detailed_outlook          360 non-null    object
#  5   temperature               360 non-null    float64
#  6   temperature_feels_like    360 non-null    float64
#  7   clouds                    360 non-null    int64
#  8   rain                      360 non-null    object
#  9   snow                      360 non-null    object
#  10  wind_speed                360 non-null    float64
#  11  wind_deg                  360 non-null    int64
#  12  humidity                  360 non-null    int64
#  13  pressure                  360 non-null    int64
#  14  information_retrieved_at  360 non-null    object
# dtypes: float64(3), int64(4), object(8)
# memory usage: 42.3+ KB

# %% [markdown]
# # Solution using `.json_normalize()`

# %% [markdown]
# **First** we need to make an API call to get our information

# %%
city = 'Berlin'
API_key = '4fe53ee5e34a7d900ed58bd74bbbb0b7'
url = (f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_key}&units=metric") 
response = requests.get(url)
json = response.json()

# %% [markdown]
# If we now try to use `.json_normalize()` on the `list` part of the json, you'll see that json_normalize can get confused when it hits a list instead of a subdictionary. Take a look at the weather column below

# %%
pd.DataFrame((json['list'])).head()
# Out:
#            dt                                               main  \
# 0  1661590800  {'temp': 20.06, 'feels_like': 20.58, 'temp_min...
# 1  1661601600  {'temp': 21.12, 'feels_like': 21.56, 'temp_min...
# 2  1661612400  {'temp': 21.39, 'feels_like': 21.73, 'temp_min...
# 3  1661623200  {'temp': 19.55, 'feels_like': 19.96, 'temp_min...
# 4  1661634000  {'temp': 18.87, 'feels_like': 19.24, 'temp_min...
#
#                                              weather        clouds  \
# 0  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 1  [{'id': 501, 'main': 'Rain', 'description': 'm...   {'all': 96}
# 2  [{'id': 500, 'main': 'Rain', 'description': 'l...   {'all': 97}
# 3  [{'id': 500, 'main': 'Rain', 'description': 'l...   {'all': 97}
# 4  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
#
#                                         wind  visibility   pop          rain  \
# 0  {'speed': 3.74, 'deg': 318, 'gust': 4.38}       10000  0.38  {'3h': 0.37}
# 1  {'speed': 4.38, 'deg': 295, 'gust': 4.72}       10000  0.87  {'3h': 4.61}
# 2  {'speed': 4.85, 'deg': 297, 'gust': 6.72}       10000  0.83  {'3h': 2.37}
# 3    {'speed': 3.9, 'deg': 320, 'gust': 7.8}       10000  0.92  {'3h': 1.62}
# 4   {'speed': 3.4, 'deg': 316, 'gust': 7.18}       10000  0.68  {'3h': 1.02}
#
#             sys               dt_txt
# 0  {'pod': 'd'}  2022-08-27 09:00:00
# 1  {'pod': 'd'}  2022-08-27 12:00:00
# 2  {'pod': 'd'}  2022-08-27 15:00:00
# 3  {'pod': 'd'}  2022-08-27 18:00:00
# 4  {'pod': 'n'}  2022-08-27 21:00:00

# %% [markdown]
# To fix this we need to flatten the nested list using the parameter `record_path`, and then select the other columns we'd like using the parameter `meta`. At the end of the json_normalize parameters we have `errors='ignore'`, which means that if ever there is a missing value in the JSON, a `NaN` gets inserted into the table. If you'd like more information, please check out the [docs](https://pandas.pydata.org/docs/reference/api/pandas.json_normalize.html)

# %%
json_norm_df_1 = pd.json_normalize(json['list'], record_path = ['weather'])
json_norm_df_1.head()
# Out:
#     id  main    description icon
# 0  500  Rain     light rain  10d
# 1  501  Rain  moderate rain  10d
# 2  500  Rain     light rain  10d
# 3  500  Rain     light rain  10d
# 4  500  Rain     light rain  10n

# %%
json_norm_df = pd.json_normalize(json['list'], 
                                record_path=['weather'], 
                                meta=['dt_txt', ['main', 'temp'], ['main', 'feels_like'], 
                                     ['clouds', 'all'], ['rain', '3h'], ['snow', '3h'], ['wind', 'speed'], 
                                     ['wind', 'deg'], ['main', 'humidity'], ['main', 'pressure']],
                                errors='ignore')

json_norm_df.head()
# Out:
#     id  main    description icon               dt_txt main.temp  \
# 0  500  Rain     light rain  10d  2022-08-27 09:00:00     20.06
# 1  501  Rain  moderate rain  10d  2022-08-27 12:00:00     21.12
# 2  500  Rain     light rain  10d  2022-08-27 15:00:00     21.39
# 3  500  Rain     light rain  10d  2022-08-27 18:00:00     19.55
# 4  500  Rain     light rain  10n  2022-08-27 21:00:00     18.87
#
#   main.feels_like clouds.all rain.3h snow.3h wind.speed wind.deg  \
# 0           20.58        100    0.37     NaN       3.74      318
# 1           21.56         96    4.61     NaN       4.38      295
# 2           21.73         97    2.37     NaN       4.85      297
# 3           19.96         97    1.62     NaN        3.9      320
# 4           19.24        100    1.02     NaN        3.4      316
#
#   main.humidity main.pressure
# 0            94          1009
# 1            87          1010
# 2            82          1011
# 3            92          1012
# 4            93          1013

# %% [markdown]
# Now let's tidy this DataFrame up by
# - dropping some columns
# - renaming some columns
# - adding some columns

# %%
# drop id and icon
json_norm_df = json_norm_df.drop(columns=['id', 'icon']).copy()

# %%
# rename some columns
json_norm_df.rename(columns={'main': 'outlook',
                             'description': 'detailed_outlook',
                             'dt_txt': 'forecast_time',
                             'main.temp': 'temperature',
                             'main.feels_like': 'temperature_feels_like',
                             'clouds.all': 'clouds',
                             'rain.3h': 'rain',
                             'snow.3h': 'snow',
                             'wind.speed': 'wind_speed',
                             'wind.deg': 'wind_deg',
                             'main.humidity': 'humidity',
                             'main.pressure': 'pressure',},
                    inplace=True)

# %%
# add some columns
json_norm_df.insert(0, 'city', json['city']['name'])
json_norm_df.insert(1, 'country', json['city']['country'])
json_norm_df['information_retrieved_at'] = now.strftime("%d/%m/%Y %H:%M:%S")

# rearrange the columns
json_norm_df = json_norm_df[['city', 'country', 'forecast_time', 'outlook', 'detailed_outlook',
       'temperature', 'temperature_feels_like', 'clouds', 'rain', 'snow',
       'wind_speed', 'wind_deg', 'humidity', 'pressure',
       'information_retrieved_at']]

json_norm_df.head()
# Out:
#      city country        forecast_time outlook detailed_outlook temperature  \
# 0  Berlin      DE  2022-08-27 09:00:00    Rain       light rain       20.06
# 1  Berlin      DE  2022-08-27 12:00:00    Rain    moderate rain       21.12
# 2  Berlin      DE  2022-08-27 15:00:00    Rain       light rain       21.39
# 3  Berlin      DE  2022-08-27 18:00:00    Rain       light rain       19.55
# 4  Berlin      DE  2022-08-27 21:00:00    Rain       light rain       18.87
#
#   temperature_feels_like clouds  rain snow wind_speed wind_deg humidity  \
# 0                  20.58    100  0.37  NaN       3.74      318       94
# 1                  21.56     96  4.61  NaN       4.38      295       87
# 2                  21.73     97  2.37  NaN       4.85      297       82
# 3                  19.96     97  1.62  NaN        3.9      320       92
# 4                  19.24    100  1.02  NaN        3.4      316       93
#
#   pressure information_retrieved_at
# 0     1009      27/08/2022 10:39:37
# 1     1010      27/08/2022 10:39:37
# 2     1011      27/08/2022 10:39:37
# 3     1012      27/08/2022 10:39:37
# 4     1013      27/08/2022 10:39:37

# %% [markdown]
# Now we have a very similar DataFrame to what we had with the for loop. Again, let's put this in a function that can take a list of cities

# %%
def get_weather_norm(cities):
  
  API_key = '4fe53ee5e34a7d900ed58bd74bbbb0b7'
  df_list = []

  for city in cities:
    url = (f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_key}&units=metric") 
    response = requests.get(url)
    json = response.json()

    json_norm_df = pd.json_normalize(json['list'], 
                                record_path=['weather'], 
                                meta=['dt_txt', ['main', 'temp'], ['main', 'feels_like'], ['clouds', 'all'], ['rain', '3h'], ['snow', '3h'], ['wind', 'speed'], ['wind', 'deg'], ['main', 'humidity'], ['main', 'pressure']], 
                                errors='ignore')
    json_norm_df.drop(columns=['id', 'icon'], inplace=True)
    json_norm_df.rename(columns={'main': 'outlook',
                             'description': 'detailed_outlook',
                             'dt_txt': 'forecast_time',
                             'main.temp': 'temperature',
                             'main.feels_like': 'temperature_feels_like',
                             'clouds.all': 'clouds',
                             'rain.3h': 'rain',
                             'snow.3h': 'snow',
                             'wind.speed': 'wind_speed',
                             'wind.deg': 'wind_deg',
                             'main.humidity': 'humidity',
                             'main.pressure': 'pressure',},
                    inplace=True)
    json_norm_df.insert(0, 'city', json['city']['name'])
    json_norm_df.insert(1, 'country', json['city']['country'])
    json_norm_df['information_retrieved_at'] = now.strftime("%d/%m/%Y %H:%M:%S")
    json_norm_df[['city', 'country', 'forecast_time', 'outlook', 'detailed_outlook',
          'temperature', 'temperature_feels_like', 'clouds', 'rain', 'snow',
          'wind_speed', 'wind_deg', 'humidity', 'pressure',
          'information_retrieved_at']]
    df_list.append(json_norm_df)
  return pd.concat(df_list, ignore_index=True)

# %%
get_weather_norm(['Berlin', 'London'])
# Out:
#       city country outlook detailed_outlook        forecast_time temperature  \
# 0   Berlin      DE    Rain       light rain  2022-08-27 09:00:00       20.61
# 1   Berlin      DE    Rain    moderate rain  2022-08-27 12:00:00       21.49
# 2   Berlin      DE    Rain       light rain  2022-08-27 15:00:00       21.57
# 3   Berlin      DE    Rain       light rain  2022-08-27 18:00:00       19.55
# 4   Berlin      DE    Rain       light rain  2022-08-27 21:00:00       18.87
# ..     ...     ...     ...              ...                  ...         ...
# 75  London      GB  Clouds  overcast clouds  2022-08-31 18:00:00       20.37
# 76  London      GB   Clear        clear sky  2022-08-31 21:00:00       17.27
# 77  London      GB   Clear        clear sky  2022-09-01 00:00:00       15.87
# 78  London      GB   Clear        clear sky  2022-09-01 03:00:00       15.57
# 79  London      GB   Clear        clear sky  2022-09-01 06:00:00       15.62
#
#    temperature_feels_like clouds  rain snow wind_speed wind_deg humidity  \
# 0                   21.13    100  0.37  NaN       3.74      318       92
# 1                   21.94     96  4.61  NaN       4.38      295       86
# 2                   21.92     97  2.37  NaN       4.85      297       82
# 3                   19.96     97  1.62  NaN        3.9      320       92
# 4                   19.24    100  1.02  NaN        3.4      316       93
# ..                    ...    ...   ...  ...        ...      ...      ...
# 75                  19.82     89   NaN  NaN       4.43       58       52
# 76                   16.7      3   NaN  NaN       4.88       43       63
# 77                  15.52      2   NaN  NaN       4.36       34       77
# 78                  15.35      1   NaN  NaN       4.23       32       83
# 79                  15.38      2   NaN  NaN       3.54       31       82
#
#    pressure information_retrieved_at
# 0      1008      27/08/2022 10:39:37
# 1      1009      27/08/2022 10:39:37
# 2      1011      27/08/2022 10:39:37
# 3      1012      27/08/2022 10:39:37
# 4      1013      27/08/2022 10:39:37
# ..      ...                      ...
# 75     1021      27/08/2022 10:39:37
# 76     1021      27/08/2022 10:39:37
# 77     1020      27/08/2022 10:39:37
# 78     1019      27/08/2022 10:39:37
# 79     1018      27/08/2022 10:39:37
#
# [80 rows x 15 columns]
